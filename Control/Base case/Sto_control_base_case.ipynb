# %% [markdown]
# Hyperparameter
# - ITERS = 10000
# - layers = [1,128,128,128,128,8]
# - BATCH = 16
# - NUM_HIDDEN = 1
# - MOMENTUM = 0.8
# - learning_rate = 1e-6
# - lr_rate = [1e-3, 1e-4, 1e-6]
# - lr_boundaries = [5000, 8000]

# %%
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as normal

tf.keras.backend.set_floatx('float64')
tf.compat.v1.enable_eager_execution()

# %%
NUM_OF_INTERNAL = 60
TOTAL_T = 60
NUM_HIDDEN = 1
MOMENTUM = 0.8
BATCH = 16
K = 2
ITERS = 10000
SEED = 12345
TEXT = "base_case" #change this one

c1 = 100 
c2 = 20
c3 = 50
c4 = 200
c5 = 1000
c6 = 300*1/2

# %%
birth =  0.000053
death =  0.000033 

alpha = 0.00135
sigma = 0.06352
beta1 = 0.2812 
beta2 = 0.15838 
beta3 = 0.0388 
delta1 = 0.28505
delta2 = 0.28269
delta3 = 0.14206
gamma = 0.30954
p1 = 0.01845
p2 = 0.1431
mu = 0.0042
sigma1 = 0.09275
sigma2 = 0.03887
sigma3 = 0.07517
sigma4 = 0.06302
sigma5 = 0.07878
sigma6 = 0.06123
sigma7 = 0.0611
sigma8 = 0.06199

N = 6629870
S0 = 3674149/N
V0 = 2845438/N
E0 = 67789/N
I10 = 12113/N
I20 = 498/N
I30 = 96/N
R0 = 28911/N
D0 = 876/N

init = [S0, V0, E0, I10, I20, I30, R0, D0]

# %%
k0 = 0.0053
k1 = -0.1676

def p1fn(alpha):
    return k0 + k1 * alpha

# %%
class Solver(object):

    def __init__(self, seed_var):
        self.valid_size = BATCH
        self.batch_size = BATCH
        
        self.num_iterations = ITERS
        self.print_frequency = 100
        self.lr_values = [1e-3, 1e-4, 1e-6]
        self.lr_boundaries = [5000, 8000]
        self.config = Config()

        self.model = WholeNet(seed_var)
        lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(self.lr_boundaries, self.lr_values)
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, epsilon=1e-7)

    def train(self):
        """Training the model"""
        start_time = time.time()
        training_history = []
        control_output = [] 
        
        dW = self.config.sample(self.valid_size)
        valid_data = dW
        for step in range(self.num_iterations+1):
            if step % self.print_frequency == 0:
                cost, row_out0 = self.model(valid_data, training=True)
                elapsed_time = time.time() - start_time
                training_history.append([step, cost, elapsed_time])
                print("step: %5u, Cost: %.4e, elapsed time: %3u" % (step, cost, elapsed_time))
            if step == self.num_iterations:
                cost1, row_out1 = self.model(valid_data, training=True)
                row_output = row_out1.numpy()
                control_output.append(row_output)
            self.train_step(self.config.sample(self.batch_size))
        self.training_history = training_history
        self.control_output = control_output

    @tf.function
    def train_step(self, train_data):
        """Updating the gradients"""
        with tf.GradientTape(persistent=True) as tape:
            loss = self.model(train_data, training = True)
        grad = tape.gradient(loss, self.model.trainable_variables)
        del tape
        self.optimizer.apply_gradients(zip(grad, self.model.trainable_variables))

# %%
class WholeNet(tf.keras.Model):
    """Building the neural network architecture"""
    def __init__(self,seed_var):
        super(WholeNet, self).__init__()
        self.config = Config()
        self.subnet = [FNNet(seed_var) for _ in range(self.config.num_time_interval)]

    def call(self, dw, training):
        x_init = tf.ones([1, self.config.dim_x], dtype=tf.dtypes.float64) * init
        time_stamp = np.arange(0, self.config.num_time_interval) * self.config.delta_t
        all_ones = tf.ones([tf.shape(dw)[0], 1], dtype=tf.dtypes.float64)

        # initial state
        x = tf.matmul(all_ones, x_init)

        # initial cost functional
        l = 0.0 
        u_set = []
        for t in range(0, self.config.num_time_interval):
            u = self.subnet[t](x, training)
            u_set.append(tf.stack([u], axis=0))   
            l = l + self.config.f_fn(time_stamp[t], x, u) * self.config.delta_t
            x = x + self.config.b_fn(time_stamp[t], x, u) * self.config.delta_t + self.config.sigma_fn(time_stamp[t], x, u) * dw[:,:,  t]

        # control variable
        control_u = tf.stack(u_set, axis=0)
        row_ave2 = tf.reduce_mean(control_u, axis=2)
        row_out1 = tf.squeeze(row_ave2, axis=[1,2])
        #print("u timepath2", row_ave2)
        
        # terminal condition
        l = l + self.config.h_fn(self.config.total_time, x)
        cost = tf.reduce_mean(l) 
        return cost, row_out1

# %%
class FNNet(tf.keras.Model):
    def __init__(self, seed_var):
        super(FNNet, self).__init__()
        self.config = Config()

        tf.random.set_seed(seed_var)
        np.random.seed(seed_var)
        
        num_hiddens = [self.config.dim_x + NUM_HIDDEN, self.config.dim_x + NUM_HIDDEN, self.config.dim_x + NUM_HIDDEN]
        self.bn_layers = [
            tf.keras.layers.BatchNormalization(
                momentum=MOMENTUM,
                epsilon=1e-6,
                beta_initializer=tf.random_normal_initializer(0.0, stddev=0.1,seed=seed_var),
                gamma_initializer=tf.random_uniform_initializer(0.1, 0.5,seed=seed_var)
            )
            for _ in range(len(num_hiddens) + 2)]
        self.dense_layers = [tf.keras.layers.Dense(num_hiddens[i],
                                                   use_bias=True,
                                                   activation='tanh')
                             for i in range(len(num_hiddens))]
        
        # final output should be gradient of size dim_u
        self.dense_layers.append(tf.keras.layers.Dense(self.config.dim_u, activation='sigmoid'))

    def call(self, x, training):
        x = self.bn_layers[0](x, training)
        for i in range(len(self.dense_layers) - 1):
            x = self.dense_layers[i](x)
            x = self.bn_layers[i+1](x, training)
            x = tf.nn.tanh(x)
        x = self.dense_layers[-1](x)
        x = self.bn_layers[-1](x, training)
        return tf.nn.tanh(x) * 0.012 + 0.016

# %%
class Config(object):
    """function config"""
    def __init__(self):
        super(Config, self).__init__()
        self.dim_x = 8
        self.dim_u = 1
        self.num_time_interval = NUM_OF_INTERNAL
        self.total_time = TOTAL_T
        self.delta_t = (self.total_time + 0.0) / self.num_time_interval
        self.sqrth = np.sqrt(self.delta_t)
        self.t_stamp = np.arange(0, self.num_time_interval) * self.delta_t

    # sample function
    def sample(self, num_sample):
        dw_sample = normal.rvs(size=[num_sample, self.dim_x, self.num_time_interval]) * self.sqrth
        return dw_sample

    # cost functional integral item
    def f_fn(self, t, x, u):
        tensors = []
        for i in range(BATCH):
            S = x[i][0]
            V = x[i][1]
            E = x[i][2]
            I1 = x[i][3]
            I2 = x[i][4]
            I3 = x[i][5]
            R = x[i][6]
            D = x[i][7]
            alpha = u[i][0]  
            cost = (c1 * alpha ** 2 + c2 * E + (c3*I1 + c4*I2 + c5*I3) + c6 * (tf.maximum(tf.cast(0, tf.float64), 1-(S+V+R)))) 
            combined_cost = tf.stack([cost], axis=0)
            tensors.append(combined_cost)
            combined_tensor = tf.stack(tensors, axis=0)
        return tf.reduce_sum(combined_tensor, 1, keepdims=True)

    # cost fuctional terminal function
    def h_fn(self, t, x):
        return 0

    def b_fn(self, t, x, u):
        tensors = []
        for i in range(BATCH):
            S = x[i][0]
            V = x[i][1]
            E = x[i][2]
            I1 = x[i][3]
            I2 = x[i][4]
            I3 = x[i][5]
            R = x[i][6]
            D = x[i][7]
            alpha = u[i][0]
            dS = birth + (- ( beta1 * I1 + beta2 * I2 + beta3 * I3) * S  - alpha * S) - death*S
            dV = (alpha * S - sigma * (beta1 * I1 + beta2 * I2 + beta3 * I3) * V) - death*V
            dE = ((beta1 * I1 + beta2 * I2 + beta3 * I3) * S  + sigma * (beta1 * I1 + beta2 * I2 + beta3 * I3) * V - gamma * E) - death*E
            dI1 = (gamma * E - (delta1 + p1fn(alpha)) * I1) - death*I1
            dI2 = (p1fn(alpha) * I1 - (delta2 + p2) * I2) - death*I2
            dI3 = (p2 * I2 - (delta3 + mu) * I3) - death*I3
            dR = (delta1 * I1+ delta2 * I2 + delta3 * I3) - death*R
            dD = (mu * I3) 
            combined_ten = tf.stack([dS, dV,dE,dI1,dI2,dI3,dR,dD], axis=0)
            tensors.append(combined_ten)
            combined_tensor = tf.stack(tensors, axis=0)
        return combined_tensor

    def sigma_fn(self, t, x, u):
        #return x
        tensors = []
        for i in range(BATCH):
            S = x[i][0]
            V = x[i][1]
            E = x[i][2]
            I1 = x[i][3]
            I2 = x[i][4]
            I3 = x[i][5]
            R = x[i][6]
            D = x[i][7]
            sig_S = sigma1*S
            sig_V = sigma2*V
            sig_E = sigma3*E
            sig_I1 = sigma4*I1
            sig_I2 = sigma5*I2
            sig_I3 = sigma6*I3
            sig_R = sigma7*R
            sig_D = sigma8*D
            combined_sig = tf.stack([sig_S, sig_V,sig_E,sig_I1,sig_I2,sig_I3,sig_R,sig_D], axis=0)
            tensors.append(combined_sig)
            combined_tensor = tf.stack(tensors, axis=0)
        return combined_tensor

# %%
output_table = np.zeros((int(round(ITERS) / 100) + 1, 2 + int(round(K))))
control_outs_table = np.zeros((int(round(K)), TOTAL_T))


def main():
    solver = Solver(seed_var=SEED)
    print('Training time %3u:' % (1))
    solver.train()
    data = np.array(solver.training_history)
    control_output_data = np.array(solver.control_output)
    k = K
    
    output = np.zeros((len(data[:, 0]), 2 + k))
    output[:, 0] = data[:, 0]
    output[:, 1] = data[:, 2]
    output[:, 2] = data[:, 1]
    output_table[:, 0] = data[:, 0]
    output_table[:, 1] = data[:, 2]
    output_table[:, 2] = data[:, 1]

    
    control_outs = np.zeros((k, len(control_output_data[0])))
    control_outs[0] = control_output_data[0]

    
    for i in range(k - 1):
        print('Training time %3u:' % (i + 2))
        solver = Solver(seed_var=12345+1+i)  
        solver.train()
        data = np.array(solver.training_history)
        control_output_data = np.array(solver.control_output)
        output[:, 3 + i] = data[:, 1]
        output_table[:, 3 + i] = data[:, 1]
        control_outs[1+i] = control_output_data[0]
        control_outs_table[1+i] = control_output_data[0]

    a = ['%d', '%.5e']
    for _ in range(k):
        a.append('%.5e')
    
    con_format = ['%.5e']
    for _ in range(len(control_output_data[0])-1):
        con_format.append('%.5e')
        
    np.savetxt('./Sto_control_Opt_Vacc_'+str(TEXT)+'.csv', control_outs, fmt=con_format, delimiter=',')
    np.savetxt('./Sto_control_Loss_'+str(TEXT)+'.csv', output, fmt=a, delimiter=',')
    print('Solving is done!')

if __name__ == '__main__':
    main()
# Out:
# Training time   1:
# step:     0, Cost: 7.8048e+02, elapsed time:   3
# step:   100, Cost: 7.7550e+02, elapsed time: 616
# step:   200, Cost: 7.7390e+02, elapsed time: 637
# step:   300, Cost: 7.7201e+02, elapsed time: 659
# step:   400, Cost: 7.6885e+02, elapsed time: 680
# step:   500, Cost: 7.6657e+02, elapsed time: 702
# step:   600, Cost: 7.6537e+02, elapsed time: 724
# step:   700, Cost: 7.6530e+02, elapsed time: 745
# step:   800, Cost: 7.6481e+02, elapsed time: 767
# step:   900, Cost: 7.6509e+02, elapsed time: 787
# step:  1000, Cost: 7.6453e+02, elapsed time: 809
# step:  1100, Cost: 7.6478e+02, elapsed time: 830
# step:  1200, Cost: 7.6277e+02, elapsed time: 852
# step:  1300, Cost: 7.6251e+02, elapsed time: 875
# step:  1400, Cost: 7.6363e+02, elapsed time: 897
# step:  1500, Cost: 7.6286e+02, elapsed time: 919
# step:  1600, Cost: 7.6442e+02, elapsed time: 940
# step:  1700, Cost: 7.6326e+02, elapsed time: 962
# step:  1800, Cost: 7.6424e+02, elapsed time: 984
# step:  1900, Cost: 7.6399e+02, elapsed time: 1006
# step:  2000, Cost: 7.6501e+02, elapsed time: 1029
# step:  2100, Cost: 7.6422e+02, elapsed time: 1051
# step:  2200, Cost: 7.6482e+02, elapsed time: 1074
# step:  2300, Cost: 7.6509e+02, elapsed time: 1099
# step:  2400, Cost: 7.6503e+02, elapsed time: 1123
# step:  2500, Cost: 7.6549e+02, elapsed time: 1148
# step:  2600, Cost: 7.6403e+02, elapsed time: 1171
# step:  2700, Cost: 7.6418e+02, elapsed time: 1195
# step:  2800, Cost: 7.6380e+02, elapsed time: 1219
# step:  2900, Cost: 7.6406e+02, elapsed time: 1244
# step:  3000, Cost: 7.6453e+02, elapsed time: 1268
# step:  3100, Cost: 7.6493e+02, elapsed time: 1289
# step:  3200, Cost: 7.6665e+02, elapsed time: 1310
# step:  3300, Cost: 7.6597e+02, elapsed time: 1331
# step:  3400, Cost: 7.6636e+02, elapsed time: 1352
# step:  3500, Cost: 7.6481e+02, elapsed time: 1373
# step:  3600, Cost: 7.6541e+02, elapsed time: 1395
# step:  3700, Cost: 7.6576e+02, elapsed time: 1417
# step:  3800, Cost: 7.6622e+02, elapsed time: 1439
# step:  3900, Cost: 7.6571e+02, elapsed time: 1461
# step:  4000, Cost: 7.6640e+02, elapsed time: 1485
# step:  4100, Cost: 7.6634e+02, elapsed time: 1511
# step:  4200, Cost: 7.6671e+02, elapsed time: 1535
# step:  4300, Cost: 7.6535e+02, elapsed time: 1559
# step:  4400, Cost: 7.6729e+02, elapsed time: 1583
# step:  4500, Cost: 7.6723e+02, elapsed time: 1607
# step:  4600, Cost: 7.6570e+02, elapsed time: 1631
# step:  4700, Cost: 7.6515e+02, elapsed time: 1654
# step:  4800, Cost: 7.6659e+02, elapsed time: 1677
# step:  4900, Cost: 7.6671e+02, elapsed time: 1699
# step:  5000, Cost: 7.6677e+02, elapsed time: 1721
# step:  5100, Cost: 7.6670e+02, elapsed time: 1743
# step:  5200, Cost: 7.6662e+02, elapsed time: 1765
# step:  5300, Cost: 7.6655e+02, elapsed time: 1788
# step:  5400, Cost: 7.6649e+02, elapsed time: 1810
# step:  5500, Cost: 7.6645e+02, elapsed time: 1833
# step:  5600, Cost: 7.6647e+02, elapsed time: 1856
# step:  5700, Cost: 7.6646e+02, elapsed time: 1879
# step:  5800, Cost: 7.6650e+02, elapsed time: 1902
# step:  5900, Cost: 7.6650e+02, elapsed time: 1924
# step:  6000, Cost: 7.6646e+02, elapsed time: 1947
# step:  6100, Cost: 7.6646e+02, elapsed time: 1969
# step:  6200, Cost: 7.6635e+02, elapsed time: 1992
# step:  6300, Cost: 7.6624e+02, elapsed time: 2015
# step:  6400, Cost: 7.6617e+02, elapsed time: 2037
# step:  6500, Cost: 7.6614e+02, elapsed time: 2059
# step:  6600, Cost: 7.6619e+02, elapsed time: 2082
# step:  6700, Cost: 7.6612e+02, elapsed time: 2103
# step:  6800, Cost: 7.6604e+02, elapsed time: 2125
# step:  6900, Cost: 7.6602e+02, elapsed time: 2145
# step:  7000, Cost: 7.6599e+02, elapsed time: 2167
# step:  7100, Cost: 7.6599e+02, elapsed time: 2188
# step:  7200, Cost: 7.6594e+02, elapsed time: 2209
# step:  7300, Cost: 7.6601e+02, elapsed time: 2231
# step:  7400, Cost: 7.6594e+02, elapsed time: 2253
# step:  7500, Cost: 7.6594e+02, elapsed time: 2274
# step:  7600, Cost: 7.6584e+02, elapsed time: 2295
# step:  7700, Cost: 7.6587e+02, elapsed time: 2316
# step:  7800, Cost: 7.6583e+02, elapsed time: 2338
# step:  7900, Cost: 7.6592e+02, elapsed time: 2359
# step:  8000, Cost: 7.6598e+02, elapsed time: 2381
# step:  8100, Cost: 7.6597e+02, elapsed time: 2402
# step:  8200, Cost: 7.6597e+02, elapsed time: 2424
# step:  8300, Cost: 7.6597e+02, elapsed time: 2446
# step:  8400, Cost: 7.6597e+02, elapsed time: 2468
# step:  8500, Cost: 7.6597e+02, elapsed time: 2489
# step:  8600, Cost: 7.6597e+02, elapsed time: 2511
# step:  8700, Cost: 7.6597e+02, elapsed time: 2532
# step:  8800, Cost: 7.6597e+02, elapsed time: 2552
# step:  8900, Cost: 7.6597e+02, elapsed time: 2573
# step:  9000, Cost: 7.6597e+02, elapsed time: 2594
# step:  9100, Cost: 7.6597e+02, elapsed time: 2615
# step:  9200, Cost: 7.6597e+02, elapsed time: 2637
# step:  9300, Cost: 7.6597e+02, elapsed time: 2658
# step:  9400, Cost: 7.6597e+02, elapsed time: 2679
# step:  9500, Cost: 7.6597e+02, elapsed time: 2700
# step:  9600, Cost: 7.6597e+02, elapsed time: 2722
# step:  9700, Cost: 7.6597e+02, elapsed time: 2743
# step:  9800, Cost: 7.6597e+02, elapsed time: 2764
# step:  9900, Cost: 7.6597e+02, elapsed time: 2785
# step: 10000, Cost: 7.6597e+02, elapsed time: 2806
# Training time   2:
# step:     0, Cost: 5.9594e+02, elapsed time:   3
# step:   100, Cost: 5.9099e+02, elapsed time: 575
# step:   200, Cost: 5.8707e+02, elapsed time: 596
# step:   300, Cost: 5.8229e+02, elapsed time: 617
# step:   400, Cost: 5.7763e+02, elapsed time: 638
# step:   500, Cost: 5.7377e+02, elapsed time: 659
# step:   600, Cost: 5.7147e+02, elapsed time: 679
# step:   700, Cost: 5.6907e+02, elapsed time: 699
# step:   800, Cost: 5.6682e+02, elapsed time: 721
# step:   900, Cost: 5.6570e+02, elapsed time: 742
# step:  1000, Cost: 5.6423e+02, elapsed time: 764
# step:  1100, Cost: 5.6223e+02, elapsed time: 786
# step:  1200, Cost: 5.6071e+02, elapsed time: 807
# step:  1300, Cost: 5.5987e+02, elapsed time: 829
# step:  1400, Cost: 5.5894e+02, elapsed time: 851
# step:  1500, Cost: 5.5789e+02, elapsed time: 873
# step:  1600, Cost: 5.5701e+02, elapsed time: 894
# step:  1700, Cost: 5.5615e+02, elapsed time: 915
# step:  1800, Cost: 5.5550e+02, elapsed time: 936
# step:  1900, Cost: 5.5507e+02, elapsed time: 958
# step:  2000, Cost: 5.5436e+02, elapsed time: 980
# step:  2100, Cost: 5.5398e+02, elapsed time: 1001
# step:  2200, Cost: 5.5361e+02, elapsed time: 1021
# step:  2300, Cost: 5.5335e+02, elapsed time: 1041
# step:  2400, Cost: 5.5298e+02, elapsed time: 1062
# step:  2500, Cost: 5.5244e+02, elapsed time: 1084
# step:  2600, Cost: 5.5252e+02, elapsed time: 1105
# step:  2700, Cost: 5.5249e+02, elapsed time: 1126
# step:  2800, Cost: 5.5248e+02, elapsed time: 1147
# step:  2900, Cost: 5.5240e+02, elapsed time: 1168
# step:  3000, Cost: 5.5200e+02, elapsed time: 1189
# step:  3100, Cost: 5.5156e+02, elapsed time: 1210
# step:  3200, Cost: 5.5127e+02, elapsed time: 1230
# step:  3300, Cost: 5.5143e+02, elapsed time: 1250
# step:  3400, Cost: 5.5156e+02, elapsed time: 1270
# step:  3500, Cost: 5.5129e+02, elapsed time: 1290
# step:  3600, Cost: 5.5097e+02, elapsed time: 1311
# step:  3700, Cost: 5.5085e+02, elapsed time: 1333
# step:  3800, Cost: 5.5079e+02, elapsed time: 1355
# step:  3900, Cost: 5.5066e+02, elapsed time: 1376
# step:  4000, Cost: 5.5068e+02, elapsed time: 1397
# step:  4100, Cost: 5.5028e+02, elapsed time: 1418
# step:  4200, Cost: 5.5037e+02, elapsed time: 1439
# step:  4300, Cost: 5.5010e+02, elapsed time: 1460
# step:  4400, Cost: 5.4980e+02, elapsed time: 1481
# step:  4500, Cost: 5.5004e+02, elapsed time: 1502
# step:  4600, Cost: 5.4984e+02, elapsed time: 1523
# step:  4700, Cost: 5.5005e+02, elapsed time: 1544
# step:  4800, Cost: 5.4991e+02, elapsed time: 1565
# step:  4900, Cost: 5.4991e+02, elapsed time: 1586
# step:  5000, Cost: 5.4972e+02, elapsed time: 1607
# step:  5100, Cost: 5.4970e+02, elapsed time: 1630
# step:  5200, Cost: 5.4969e+02, elapsed time: 1651
# step:  5300, Cost: 5.4969e+02, elapsed time: 1672
# step:  5400, Cost: 5.4967e+02, elapsed time: 1694
# step:  5500, Cost: 5.4966e+02, elapsed time: 1717
# step:  5600, Cost: 5.4967e+02, elapsed time: 1740
# step:  5700, Cost: 5.4965e+02, elapsed time: 1762
# step:  5800, Cost: 5.4965e+02, elapsed time: 1784
# step:  5900, Cost: 5.4962e+02, elapsed time: 1805
# step:  6000, Cost: 5.4962e+02, elapsed time: 1825
# step:  6100, Cost: 5.4962e+02, elapsed time: 1846
# step:  6200, Cost: 5.4961e+02, elapsed time: 1866
# step:  6300, Cost: 5.4956e+02, elapsed time: 1887
# step:  6400, Cost: 5.4954e+02, elapsed time: 1907
# step:  6500, Cost: 5.4954e+02, elapsed time: 1927
# step:  6600, Cost: 5.4951e+02, elapsed time: 1948
# step:  6700, Cost: 5.4953e+02, elapsed time: 1968
# step:  6800, Cost: 5.4950e+02, elapsed time: 1989
# step:  6900, Cost: 5.4946e+02, elapsed time: 2009
# step:  7000, Cost: 5.4946e+02, elapsed time: 2030
# step:  7100, Cost: 5.4948e+02, elapsed time: 2050
# step:  7200, Cost: 5.4945e+02, elapsed time: 2071
# step:  7300, Cost: 5.4945e+02, elapsed time: 2092
# step:  7400, Cost: 5.4943e+02, elapsed time: 2113
# step:  7500, Cost: 5.4944e+02, elapsed time: 2134
# step:  7600, Cost: 5.4945e+02, elapsed time: 2156
# step:  7700, Cost: 5.4945e+02, elapsed time: 2176
# step:  7800, Cost: 5.4945e+02, elapsed time: 2197
# step:  7900, Cost: 5.4943e+02, elapsed time: 2216
# step:  8000, Cost: 5.4942e+02, elapsed time: 2236
# step:  8100, Cost: 5.4942e+02, elapsed time: 2256
# step:  8200, Cost: 5.4942e+02, elapsed time: 2275
# step:  8300, Cost: 5.4942e+02, elapsed time: 2294
# step:  8400, Cost: 5.4942e+02, elapsed time: 2313
# step:  8500, Cost: 5.4942e+02, elapsed time: 2332
# step:  8600, Cost: 5.4942e+02, elapsed time: 2351
# step:  8700, Cost: 5.4942e+02, elapsed time: 2371
# step:  8800, Cost: 5.4942e+02, elapsed time: 2392
# step:  8900, Cost: 5.4942e+02, elapsed time: 2413
# step:  9000, Cost: 5.4942e+02, elapsed time: 2435
# step:  9100, Cost: 5.4942e+02, elapsed time: 2457
# step:  9200, Cost: 5.4942e+02, elapsed time: 2478
# step:  9300, Cost: 5.4942e+02, elapsed time: 2499
# step:  9400, Cost: 5.4942e+02, elapsed time: 2521
# step:  9500, Cost: 5.4942e+02, elapsed time: 2542
# step:  9600, Cost: 5.4942e+02, elapsed time: 2564
# step:  9700, Cost: 5.4942e+02, elapsed time: 2585
# step:  9800, Cost: 5.4942e+02, elapsed time: 2605
# step:  9900, Cost: 5.4942e+02, elapsed time: 2625
# step: 10000, Cost: 5.4942e+02, elapsed time: 2646
# Solving is done!

# %%
loss_val = output_table[:, 2]
for i in range(K-1):
    loss_val = loss_val + output_table[:, i+3]
average_cost = loss_val/K
print(average_cost)
# Out:
# [688.2117856  683.24329513 680.48167422 677.14967447 673.23787291
#  670.16956415 668.41907765 667.18380413 665.81728905 665.39688187
#  664.3792943  663.50423698 661.73634952 661.19162514 661.28584788
#  660.37683774 660.71033484 659.70476997 659.87236028 659.53036455
#  659.68450238 659.09910358 659.21900199 659.22093195 659.00590417
#  658.96825699 658.27466199 658.33091376 658.14188045 658.23091201
#  658.26452852 658.24105754 658.95936484 658.69848135 658.95999438
#  658.04685125 658.18922496 658.30310067 658.50580603 658.18837882
#  658.53786505 658.30787207 658.54415647 657.72370508 658.5455562
#  658.63319039 657.76927995 657.59981098 658.25019421 658.3068684
#  658.24581993 658.20015572 658.15586974 658.11697464 658.08126976
#  658.05550571 658.07026049 658.05601839 658.07503085 658.06245537
#  658.03946657 658.04172612 657.98265577 657.89805012 657.85301819
#  657.84060057 657.84812589 657.82457146 657.77269558 657.74027489
#  657.72392324 657.73525193 657.6962044  657.72730743 657.68562803
#  657.6884214  657.6474969  657.65820669 657.64409953 657.67735381
#  657.70031012 657.69948656 657.69950405 657.69898441 657.69877175
#  657.69857258 657.69806702 657.69795679 657.69724969 657.69687907
#  657.69638435 657.69596025 657.69614487 657.69537055 657.69559818
#  657.69525971 657.69494651 657.69505744 657.69554036 657.69517649
#  657.69495223]

# %%
print(output_table)
#cost1 = output_table[:, 2]
#cost2 = output_table[:, 3]
#cost3 = output_table[:, 4]

# Compute averages
#average_cost = (cost1 + cost2+ cost3) / 3
#print(average_cost)
# Out:
# [[0.00000000e+00 3.86992407e+00 7.80483403e+02 5.95940168e+02]
#  [1.00000000e+02 6.16127096e+02 7.75496271e+02 5.90990319e+02]
#  [2.00000000e+02 6.37171418e+02 7.73895751e+02 5.87067598e+02]
#  [3.00000000e+02 6.59023650e+02 7.72005998e+02 5.82293351e+02]
#  [4.00000000e+02 6.80380362e+02 7.68849392e+02 5.77626354e+02]
#  [5.00000000e+02 7.02295187e+02 7.66567471e+02 5.73771658e+02]
#  [6.00000000e+02 7.24361577e+02 7.65365700e+02 5.71472455e+02]
#  [7.00000000e+02 7.45714848e+02 7.65298457e+02 5.69069152e+02]
#  [8.00000000e+02 7.67051167e+02 7.64810328e+02 5.66824250e+02]
#  [9.00000000e+02 7.87964307e+02 7.65091015e+02 5.65702748e+02]
#  [1.00000000e+03 8.09399473e+02 7.64531994e+02 5.64226595e+02]
#  [1.10000000e+03 8.30945719e+02 7.64776525e+02 5.62231949e+02]
#  [1.20000000e+03 8.52848094e+02 7.62766783e+02 5.60705916e+02]
#  [1.30000000e+03 8.75420210e+02 7.62508368e+02 5.59874882e+02]
#  [1.40000000e+03 8.97507397e+02 7.63632619e+02 5.58939077e+02]
#  [1.50000000e+03 9.19415440e+02 7.62861509e+02 5.57892166e+02]
#  [1.60000000e+03 9.40845960e+02 7.64415149e+02 5.57005521e+02]
#  [1.70000000e+03 9.62279780e+02 7.63259899e+02 5.56149641e+02]
#  [1.80000000e+03 9.84634812e+02 7.64243213e+02 5.55501508e+02]
#  [1.90000000e+03 1.00657166e+03 7.63991835e+02 5.55068894e+02]
#  [2.00000000e+03 1.02921894e+03 7.65011271e+02 5.54357734e+02]
#  [2.10000000e+03 1.05112870e+03 7.64220508e+02 5.53977699e+02]
#  [2.20000000e+03 1.07463333e+03 7.64824985e+02 5.53613019e+02]
#  [2.30000000e+03 1.09900994e+03 7.65088705e+02 5.53353159e+02]
#  [2.40000000e+03 1.12352698e+03 7.65031759e+02 5.52980049e+02]
#  [2.50000000e+03 1.14808818e+03 7.65494666e+02 5.52441848e+02]
#  [2.60000000e+03 1.17175212e+03 7.64028747e+02 5.52520577e+02]
#  [2.70000000e+03 1.19573342e+03 7.64175654e+02 5.52486174e+02]
#  [2.80000000e+03 1.21963430e+03 7.63800869e+02 5.52482892e+02]
#  [2.90000000e+03 1.24416295e+03 7.64063658e+02 5.52398166e+02]
#  [3.00000000e+03 1.26811454e+03 7.64527057e+02 5.52002000e+02]
#  [3.10000000e+03 1.28976645e+03 7.64926423e+02 5.51555692e+02]
#  [3.20000000e+03 1.31059472e+03 7.66651444e+02 5.51267285e+02]
#  [3.30000000e+03 1.33146911e+03 7.65969342e+02 5.51427621e+02]
#  [3.40000000e+03 1.35261993e+03 7.66362235e+02 5.51557754e+02]
#  [3.50000000e+03 1.37383684e+03 7.64806867e+02 5.51286835e+02]
#  [3.60000000e+03 1.39581387e+03 7.65408188e+02 5.50970262e+02]
#  [3.70000000e+03 1.41783296e+03 7.65759527e+02 5.50846675e+02]
#  [3.80000000e+03 1.43972115e+03 7.66223714e+02 5.50787898e+02]
#  [3.90000000e+03 1.46160275e+03 7.65712473e+02 5.50664285e+02]
#  [4.00000000e+03 1.48592323e+03 7.66398097e+02 5.50677633e+02]
#  [4.10000000e+03 1.51132496e+03 7.66338136e+02 5.50277608e+02]
#  [4.20000000e+03 1.53563913e+03 7.66714446e+02 5.50373867e+02]
#  [4.30000000e+03 1.55986460e+03 7.65347767e+02 5.50099644e+02]
#  [4.40000000e+03 1.58387140e+03 7.67294966e+02 5.49796146e+02]
#  [4.50000000e+03 1.60787148e+03 7.67227528e+02 5.50038853e+02]
#  [4.60000000e+03 1.63172871e+03 7.65697697e+02 5.49840863e+02]
#  [4.70000000e+03 1.65487480e+03 7.65145689e+02 5.50053933e+02]
#  [4.80000000e+03 1.67791075e+03 7.66589954e+02 5.49910434e+02]
#  [4.90000000e+03 1.69995780e+03 7.66705613e+02 5.49908124e+02]
#  [5.00000000e+03 1.72171652e+03 7.66774283e+02 5.49717357e+02]
#  [5.10000000e+03 1.74334323e+03 7.66699013e+02 5.49701298e+02]
#  [5.20000000e+03 1.76593791e+03 7.66620638e+02 5.49691102e+02]
#  [5.30000000e+03 1.78847598e+03 7.66546662e+02 5.49687287e+02]
#  [5.40000000e+03 1.81091690e+03 7.66488105e+02 5.49674434e+02]
#  [5.50000000e+03 1.83340368e+03 7.66446499e+02 5.49664513e+02]
#  [5.60000000e+03 1.85657679e+03 7.66474612e+02 5.49665909e+02]
#  [5.70000000e+03 1.87991246e+03 7.66458534e+02 5.49653503e+02]
#  [5.80000000e+03 1.90249096e+03 7.66501494e+02 5.49648568e+02]
#  [5.90000000e+03 1.92490314e+03 7.66500252e+02 5.49624659e+02]
#  [6.00000000e+03 1.94704979e+03 7.66461604e+02 5.49617329e+02]
#  [6.10000000e+03 1.96985542e+03 7.66461329e+02 5.49622123e+02]
#  [6.20000000e+03 1.99261587e+03 7.66354107e+02 5.49611204e+02]
#  [6.30000000e+03 2.01511246e+03 7.66238147e+02 5.49557953e+02]
#  [6.40000000e+03 2.03746235e+03 7.66170972e+02 5.49535064e+02]
#  [6.50000000e+03 2.05992481e+03 7.66138535e+02 5.49542666e+02]
#  [6.60000000e+03 2.08255702e+03 7.66186463e+02 5.49509789e+02]
#  [6.70000000e+03 2.10351181e+03 7.66121396e+02 5.49527747e+02]
#  [6.80000000e+03 2.12506879e+03 7.66044884e+02 5.49500507e+02]
#  [6.90000000e+03 2.14586005e+03 7.66017106e+02 5.49463444e+02]
#  [7.00000000e+03 2.16717431e+03 7.65989477e+02 5.49458369e+02]
#  [7.10000000e+03 2.18866191e+03 7.65993505e+02 5.49476999e+02]
#  [7.20000000e+03 2.20997604e+03 7.65938502e+02 5.49453907e+02]
#  [7.30000000e+03 2.23147622e+03 7.66009172e+02 5.49445443e+02]
#  [7.40000000e+03 2.25327980e+03 7.65936708e+02 5.49434549e+02]
#  [7.50000000e+03 2.27431702e+03 7.65939866e+02 5.49436977e+02]
#  [7.60000000e+03 2.29537105e+03 7.65841463e+02 5.49453530e+02]
#  [7.70000000e+03 2.31648877e+03 7.65868897e+02 5.49447516e+02]
#  [7.80000000e+03 2.33820824e+03 7.65834755e+02 5.49453444e+02]
#  [7.90000000e+03 2.35951976e+03 7.65924511e+02 5.49430196e+02]
#  [8.00000000e+03 2.38114940e+03 7.65976260e+02 5.49424360e+02]
#  [8.10000000e+03 2.40236859e+03 7.65974365e+02 5.49424608e+02]
#  [8.20000000e+03 2.42460258e+03 7.65974226e+02 5.49424782e+02]
#  [8.30000000e+03 2.44690534e+03 7.65973481e+02 5.49424488e+02]
#  [8.40000000e+03 2.46859495e+03 7.65973195e+02 5.49424348e+02]
#  [8.50000000e+03 2.48986427e+03 7.65972840e+02 5.49424305e+02]
#  [8.60000000e+03 2.51104164e+03 7.65971899e+02 5.49424235e+02]
#  [8.70000000e+03 2.53211728e+03 7.65972086e+02 5.49423827e+02]
#  [8.80000000e+03 2.55295330e+03 7.65970934e+02 5.49423565e+02]
#  [8.90000000e+03 2.57353367e+03 7.65970701e+02 5.49423057e+02]
#  [9.00000000e+03 2.59432426e+03 7.65970078e+02 5.49422691e+02]
#  [9.10000000e+03 2.61545405e+03 7.65969337e+02 5.49422584e+02]
#  [9.20000000e+03 2.63716770e+03 7.65969668e+02 5.49422622e+02]
#  [9.30000000e+03 2.65861969e+03 7.65968781e+02 5.49421960e+02]
#  [9.40000000e+03 2.67961176e+03 7.65969442e+02 5.49421755e+02]
#  [9.50000000e+03 2.70067432e+03 7.65968753e+02 5.49421766e+02]
#  [9.60000000e+03 2.72218537e+03 7.65968442e+02 5.49421451e+02]
#  [9.70000000e+03 2.74342340e+03 7.65968727e+02 5.49421388e+02]
#  [9.80000000e+03 2.76446403e+03 7.65969474e+02 5.49421606e+02]
#  [9.90000000e+03 2.78555062e+03 7.65968825e+02 5.49421528e+02]
#  [1.00000000e+04 2.80619956e+03 7.65968512e+02 5.49421393e+02]]

# %%
t = np.linspace(0, len(average_cost), len(average_cost))
fig, ax0 = plt.subplots(1, 1, figsize =(16,6), dpi = 120, sharey = True)
ax0.plot(t, average_cost, lw = 0.5, color = 'mediumblue', label = 'average_cost')
ax0.set_xlabel('Iterations', fontsize = 12)
ax0.set_ylabel('Loss', fontsize = 12)
ax0.set_title('Loss function over time', fontsize = 12)
plt.savefig('Loss_'+str(TEXT)+'.png')

# %%
print(control_outs_table[1:2,:].flatten())
t = np.linspace(0, len(control_outs_table[1:2,:].flatten()),len(control_outs_table[1:2,:].flatten()))
fig, ax0 = plt.subplots(1, 1, figsize =(16,6), dpi = 120, sharey = True)
ax0.plot(control_outs_table[1:2,:].flatten(), lw = 0.5, color = 'mediumblue', label = 'average_cost')
ax0.set_xlabel('Time [days]', fontsize = 12)
ax0.set_ylabel('Vaccination rate', fontsize = 12)
ax0.set_title('Opt vacc', fontsize = 12)
plt.savefig('Opt vacc_'+str(TEXT)+'.png')
# Out:
# [0.02779236 0.02779371 0.02777925 0.02776547 0.02774524 0.02771905
#  0.02769274 0.02765901 0.02762101 0.02759398 0.02758989 0.02748173
#  0.02735633 0.0272533  0.02700834 0.02682919 0.02669805 0.0260277
#  0.02591211 0.02538801 0.02543491 0.02521816 0.02483456 0.02442329
#  0.02411917 0.02359467 0.02262074 0.02239217 0.02143359 0.02112951
#  0.0205083  0.01975806 0.01890472 0.01826628 0.01757049 0.01686465
#  0.01582707 0.01454084 0.01410717 0.0137237  0.01287079 0.01200207
#  0.01170837 0.01122413 0.01048612 0.00976974 0.00904998 0.00841472
#  0.00729088 0.00631825 0.005784   0.00529809 0.00481598 0.00456127
#  0.00438917 0.0043052  0.00426843 0.00425405 0.00425232 0.00424851]
