# %% [raw]
# Hyperparameter
# - alpha1 = 1, alpha2 = 1
# - epoch = 100000
# - layers = [1,128,128,128,128,16]
# - neurons = 128
# - num of MC = 10
# - learning_rate = 1e-6

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import pandas as pd
import matplotlib
import matplotlib as mpl
import matplotlib.dates as dates
import matplotlib.pyplot as plt
import copy
import math
import scipy as sp
from scipy import optimize
from scipy.integrate import odeint
from scipy.interpolate import CubicSpline
from prettytable import PrettyTable  
import datetime as dt
import timeit
import time
import os
import sys
import time
import random
from sklearn.metrics import mean_squared_error, mean_absolute_error
sys.path.insert(0, '../../Utilities/')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
np.set_printoptions(threshold=np.inf)
# Out:
# WARNING:tensorflow:From /Users/mir/opt/anaconda3/envs/tensorflow_data/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
data = pd.read_csv("EINN_21day.csv")

alpha1 = 1.0 #data
alpha2 = 1.0

N0 = 6629870
lb = 0
ub = 21

POINTS = 1
SEED = 123
GRID = 9

npoints = ub * POINTS
epochs = 100000

layers = [1,128,128,128,128,16]
n_mc = 10
learning_rate = 1e-6
length = int(ub-lb)

# %%
birth_rt = 0.000053
death_rt = 0.000033

alpha_cal = 0.00171
sigma_cal = 0.06353
beta1_cal = 0.28121
beta2_cal = 0.15838
beta3_cal = 0.03881
delta1_cal = 0.28505
delta2_cal = 0.28269
delta3_cal = 0.14206
gamma_cal = 0.30959
p1_cal = 0.02089
p2_cal = 0.14311
mu_cal = 0.00492
sigma1_cal = 0.09278
sigma2_cal = 0.03863
sigma3_cal = 0.07516
sigma4_cal = 0.06305
sigma5_cal = 0.07877
sigma6_cal = 0.06125
sigma7_cal = 0.06111
sigma8_cal = 0.06199

# %%
class ClipConstraint(tf.keras.constraints.Constraint):
    def __init__(self, min_value, max_value):
        self.min_value = min_value
        self.max_value = max_value

    def __call__(self, w):
        return tf.clip_by_value(w, self.min_value, self.max_value)

class SIR:
    def __init__(self, S, V, E, I1, I2, I3, R, D, T, layers, alpha1, alpha2, dW1, dW2, dW3, dW4, dW5, dW6, dW7, dW8, n_mc):
        self.t = T
        self.S = S
        self.V = V
        self.E = E
        self.I1 = I1
        self.I2 = I2
        self.I3 = I3
        self.R = R
        self.D = D
        self.dW1 = dW1
        self.dW2 = dW2
        self.dW3 = dW3
        self.dW4 = dW4
        self.dW5 = dW5
        self.dW6 = dW6
        self.dW7 = dW7
        self.dW8 = dW8
        
        self.learning_rate = learning_rate 
        
        self.n_mc = n_mc
        self.alpha1, self.alpha2 = alpha1, alpha2


        self.layers = layers
        self.lb = T.min()
        self.ub = T.max()

        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        self.birth = tf.Variable(birth_rt ,dtype=tf.float32,trainable=False)
        self.dead = tf.Variable(death_rt,dtype=tf.float32,trainable=False)
        
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        
        #trainable parameters
        self.grid = GRID
        self.alpha = tf.Variable(alpha_cal,dtype=tf.float32,trainable=False)
        self.sigma = tf.Variable(sigma_cal,dtype=tf.float32,trainable=False)
        self.beta1 = tf.Variable(beta1_cal,dtype=tf.float32,trainable=False)
        self.beta2 = tf.Variable(beta2_cal,dtype=tf.float32,trainable=False)
        self.beta3 = tf.Variable(beta3_cal,dtype=tf.float32,trainable=False)
        self.delta1 = tf.Variable(delta1_cal,dtype=tf.float32,trainable=False)
        self.delta2 = tf.Variable(delta2_cal,dtype=tf.float32,trainable=False)
        self.delta3 = tf.Variable(delta3_cal,dtype=tf.float32,trainable=False)
        self.mu = tf.Variable(mu_cal,dtype=tf.float32,trainable=False)
        self.gamma = tf.Variable(gamma_cal,dtype=tf.float32,trainable=False)
        self.p1 = tf.Variable(p1_cal,dtype=tf.float32,trainable=False)
        self.p2 = tf.Variable(p2_cal,dtype=tf.float32,trainable=False)
        self.sigma1 = tf.Variable(sigma1_cal,dtype=tf.float32,trainable=False)
        self.sigma2 = tf.Variable(sigma2_cal,dtype=tf.float32,trainable=False)
        self.sigma3 = tf.Variable(sigma3_cal,dtype=tf.float32,trainable=False)
        self.sigma4 = tf.Variable(sigma4_cal,dtype=tf.float32,trainable=False)
        self.sigma5 = tf.Variable(sigma5_cal,dtype=tf.float32,trainable=False)
        self.sigma6 = tf.Variable(sigma6_cal,dtype=tf.float32,trainable=False)
        self.sigma7 = tf.Variable(sigma7_cal,dtype=tf.float32,trainable=False)
        self.sigma8 = tf.Variable(sigma8_cal,dtype=tf.float32,trainable=False)


        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        # Initialize NN
        self.weights1, self.biases1 = self.initialize_NN(self.layers)
        self.weights2, self.biases2 = self.initialize_NN(self.layers)
        self.weights3, self.biases3 = self.initialize_NN(self.layers)
        self.weights4, self.biases4 = self.initialize_NN(self.layers)
        self.weights5, self.biases5 = self.initialize_NN(self.layers)
        self.weights6, self.biases6 = self.initialize_NN(self.layers)
        self.weights7, self.biases7 = self.initialize_NN(self.layers)
        self.weights8, self.biases8 = self.initialize_NN(self.layers)
        self.weights9, self.biases9 = self.initialize_NN(self.layers)
        self.weights10, self.biases10 = self.initialize_NN(self.layers)
        self.weights11, self.biases11 = self.initialize_NN(self.layers)
        self.weights12, self.biases12 = self.initialize_NN(self.layers)
        self.weights13, self.biases13 = self.initialize_NN(self.layers)
        self.weights14, self.biases14 = self.initialize_NN(self.layers)
        self.weights15, self.biases15 = self.initialize_NN(self.layers)
        self.weights16, self.biases16 = self.initialize_NN(self.layers)
     
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.S_tf = tf.placeholder(tf.float32, shape=[None, self.S.shape[1]])
        self.V_tf = tf.placeholder(tf.float32, shape=[None, self.V.shape[1]])
        self.E_tf = tf.placeholder(tf.float32, shape=[None, self.E.shape[1]])
        self.I1_tf = tf.placeholder(tf.float32, shape=[None, self.I1.shape[1]])
        self.I2_tf = tf.placeholder(tf.float32, shape=[None, self.I2.shape[1]])
        self.I3_tf = tf.placeholder(tf.float32, shape=[None, self.I3.shape[1]])
        self.R_tf = tf.placeholder(tf.float32, shape=[None, self.R.shape[1]])
        self.D_tf = tf.placeholder(tf.float32, shape=[None, self.D.shape[1]])
        self.dW1_tf = tf.placeholder(tf.float32, shape=[None, self.dW1.shape[1]])
        self.dW2_tf = tf.placeholder(tf.float32, shape=[None, self.dW2.shape[1]])
        self.dW3_tf = tf.placeholder(tf.float32, shape=[None, self.dW3.shape[1]])
        self.dW4_tf = tf.placeholder(tf.float32, shape=[None, self.dW4.shape[1]])
        self.dW5_tf = tf.placeholder(tf.float32, shape=[None, self.dW5.shape[1]])
        self.dW6_tf = tf.placeholder(tf.float32, shape=[None, self.dW6.shape[1]])
        self.dW7_tf = tf.placeholder(tf.float32, shape=[None, self.dW7.shape[1]])
        self.dW8_tf = tf.placeholder(tf.float32, shape=[None, self.dW8.shape[1]])
        
        #lossess
        self.total_loss =[]
        self.loss_data =[]
        self.loss_res =[]
        
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        self.S_pred, self.V_pred, self.E_pred, self.I1_pred, self.I2_pred, self.I3_pred, self.R_pred, self.D_pred,_,_,_,_,_,_,_,_ = self.net_sir(self.t_tf)
        
        self.l_em, self.s_list, self.v_list, self.e_list, self.i1_list, self.i2_list, self.i3_list, self.r_list, self.d_list = self.euler_maruyama_loss(self.t_tf, self.n_mc) 
        
        # E-M Loss
        self.lossRes = tf.reduce_mean(tf.square(self.l_em)) 

        # Data loss
        self.S_loss =tf.reduce_mean(tf.square(self.S_tf - self.S_pred))
        self.V_loss =tf.reduce_mean(tf.square(self.V_tf - self.V_pred))
        self.E_loss =tf.reduce_mean(tf.square(self.E_tf - self.E_pred))
        self.I1_loss =tf.reduce_mean(tf.square(self.I1_tf - self.I1_pred))
        self.I2_loss =tf.reduce_mean(tf.square(self.I2_tf - self.I2_pred))
        self.I3_loss =tf.reduce_mean(tf.square(self.I3_tf - self.I3_pred))
        self.R_loss =tf.reduce_mean(tf.square(self.R_tf - self.R_pred))
        self.D_loss =tf.reduce_mean(tf.square(self.D_tf - self.D_pred))  
        self.lossData = self.S_loss + self.V_loss + self.E_loss + self.I1_loss + self.I2_loss + self.I3_loss + self.R_loss + self.D_loss
        
        # Total loss for PINN
        alpha1, alpha2 = self.alpha1, self.alpha2
        self.loss = alpha1*self.lossData + alpha2*self.lossRes
        
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate) 
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)
        
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        # Optimizers
        init = tf.global_variables_initializer()
        self.sess.run(init)
         
        
    def initialize_NN(self, layers): 
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        weights = []
        biases = []
        num_layers = len(layers)
        
        for l in range(0,num_layers-1):
            tf.set_random_seed(SEED)
            np.random.seed(SEED)
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
    
    def xavier_init(self, size):
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev, seed=SEED), dtype=tf.float32)
    

    def neural_net(self, X, weights, biases):
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        num_layers = len(weights) + 1
        H = 2.0*(X - self.lb)/(self.ub - self.lb) - 1.0 # standardized the input
        for l in range(0, num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.nn.sigmoid(tf.add(tf.matmul(H, W), b))
        return Y
    
    def net_sir(self, t):
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        SVEI3RD = self.neural_net(t, self.weights1, self.biases1)
        S = SVEI3RD[:,0:1]
        V = SVEI3RD[:,1:2]
        E = SVEI3RD[:,2:3]
        I1 = SVEI3RD[:,3:4]
        I2 = SVEI3RD[:,4:5]
        I3 = SVEI3RD[:,5:6]
        R = SVEI3RD[:,6:7]
        D = SVEI3RD[:,7:8]
        Dw1 = SVEI3RD[:,8:9]
        Dw2 = SVEI3RD[:,9:10]
        Dw3 = SVEI3RD[:,10:11]
        Dw4 = SVEI3RD[:,11:12]
        Dw5 = SVEI3RD[:,12:13]
        Dw6 = SVEI3RD[:,13:14]
        Dw7 = SVEI3RD[:,14:15]
        Dw8 = SVEI3RD[:,15:16]
        return S, V, E, I1, I2, I3, R, D, Dw1, Dw2, Dw3, Dw4, Dw5, Dw6, Dw7, Dw8
    
    # Define the SIR model equations
    def SIR_equations(self, S, V, E, I1, I2, I3, R, D, birth, dead, alpha, sigma, beta1, beta2, beta3, 
                      delta1, delta2, delta3, mu, gamma, p1, p2, dW1, dW2, dW3, dW4, dW5, dW6, dW7, dW8, 
                      sigma1, sigma2, sigma3, sigma4, sigma5, sigma6, sigma7, sigma8, dt):

        dS = (birth - ( beta1 * I1 + beta2 * I2 + beta3 * I3) * S  - alpha * S - dead*S) * dt +  (sigma1*S) * math.sqrt(dt) * dW1
        dV = (alpha * S - sigma * (beta1 * I1 + beta2 * I2 + beta3 * I3) * V - dead*V) *dt +  (sigma2*V) * math.sqrt(dt) * dW2
        dE = ((beta1 * I1 + beta2 * I2 + beta3 * I3) * S  + sigma * (beta1 * I1 + beta2 * I2 + beta3 * I3) * V  - gamma * E- dead*E) * dt+ (sigma3*E) * math.sqrt(dt) * dW3
        dI1 = (gamma * E - (delta1 + p1) * I1- dead*I1) * dt + (sigma4*I1) * math.sqrt(dt) * dW4
        dI2 = (p1 * I1 - (delta2 + p2) * I2- dead*I2)* dt + (sigma5*I2) * math.sqrt(dt) * dW5
        dI3 = (p2 * I2 - (delta3 + mu) * I3- dead*I3) * dt +  (sigma6*I3) * math.sqrt(dt) * dW6
        dR = (delta1 * I1+ delta2 * I2 + delta3 * I3- dead*R) * dt + (sigma7*R) * math.sqrt(dt) * dW7
        dD = (mu * I3) * dt +  (sigma8*D) * math.sqrt(dt) * dW8
        return dS, dV, dE, dI1, dI2, dI3, dR, dD
    
    # Define the Euler-Maruyama discretization loss
    def euler_maruyama_loss(self, t, n_mc):

        birth = self.birth
        dead = self.dead
        alpha = self.alpha
        sigma = self.sigma
        beta1 = self.beta1
        beta2 = self.beta2
        beta3 = self.beta3
        delta1 = self.delta1
        delta2 = self.delta2
        delta3 = self.delta3
        mu = self.mu
        gamma = self.gamma
        p1 = self.p1
        p2 = self.p2
        sigma1 = self.sigma1
        sigma2 = self.sigma2
        sigma3 = self.sigma3
        sigma4 = self.sigma4
        sigma5 = self.sigma5
        sigma6 = self.sigma6
        sigma7 = self.sigma7
        sigma8 = self.sigma8
        
        dt = ub/npoints
        S_list = []
        V_list = []
        E_list = []
        I1_list = []
        I2_list = []
        I3_list = []
        R_list = []
        D_list = []
        loss = []
        
        for _ in range(n_mc):
            tf.set_random_seed(SEED)
            np.random.seed(SEED)
            
            # obtain the NN's outputs 
            S, V, E, I1, I2, I3, R, D, dW1, dW2, dW3, dW4, dW5, dW6, dW7, dW8 = self.net_sir(t)

            S_list.append(S)
            V_list.append(V)
            E_list.append(E)
            I1_list.append(I1)
            I2_list.append(I2)
            I3_list.append(I3)
            R_list.append(R)
            D_list.append(D)

            dS, dV, dE, dI1, dI2, dI3, dR, dD = self.SIR_equations(S, V, E, I1, I2, I3, R, D, birth, dead, alpha, sigma, 
                                                                   beta1, beta2, beta3, delta1, delta2, delta3, mu, gamma,
                                                                   p1, p2, dW1, dW2, dW3, dW4, dW5, dW6, dW7, dW8, 
                                                                   sigma1, sigma2, sigma3, sigma4, sigma5, sigma6, sigma7, sigma8, dt)
            
            # obtained the physical-informed data points
            S_phy = S + dS
            V_phy = V + dV
            E_phy = E + dE
            I1_phy = I1 + dI1
            I2_phy = I2 + dI2
            I3_phy = I3 + dI3
            R_phy = R + dR
            D_phy = D + dD

            e1 =  S_phy[:-1] - S[1:]
            e2 = V_phy[:-1] - V[1:]
            e3 = E_phy[:-1] - E[1:]
            e4 = I1_phy[:-1]- I1[1:]
            e5 = I2_phy[:-1] - I2[1:]
            e6 = I3_phy[:-1] - I3[1:]
            e7 = R_phy[:-1] - R[1:]
            e8 = D_phy[:-1] - D[1:]
            
            l = tf.reduce_mean(tf.square(e1)) + tf.reduce_mean(tf.square(e2)) + tf.reduce_mean(tf.square(e3)) +\
                tf.reduce_mean(tf.square(e4)) + tf.reduce_mean(tf.square(e5)) + tf.reduce_mean(tf.square(e6)) +\
                tf.reduce_mean(tf.square(e7)) + tf.reduce_mean(tf.square(e8))
            
            loss.append(l)
            
        l_em = tf.stack(tf.reduce_mean(loss), axis=0)

        return l_em, S_list, V_list, E_list, I1_list, I2_list, I3_list, R_list, D_list
    
    def callback(self, loss):
        print('Loss: %.3e' % (loss))

    def train(self, nIter):
        tf.set_random_seed(SEED)
        tf_dict = {self.t_tf: self.t, 
                   self.S_tf: self.S,
                   self.V_tf: self.V,
                   self.E_tf: self.E,
                   self.I1_tf: self.I1,
                   self.I2_tf: self.I2,
                   self.I3_tf: self.I3,
                   self.R_tf: self.R,
                   self.D_tf: self.D,
                   self.dW1_tf:self.dW1,
                   self.dW2_tf:self.dW2,
                   self.dW3_tf:self.dW3,
                   self.dW4_tf:self.dW4,
                   self.dW5_tf:self.dW5,
                   self.dW6_tf:self.dW6,
                   self.dW7_tf:self.dW7,
                   self.dW8_tf:self.dW8
                  }
                   
        start_time = time.time()
        loss_seq = []
        for it in range(nIter):
            tf.set_random_seed(SEED)
            np.random.seed(SEED)
            self.sess.run(self.train_op_Adam, tf_dict)
            loss_t = self.sess.run(self.loss, tf_dict)
            loss_d = self.sess.run(self.lossData, tf_dict)
            loss_p = self.sess.run(self.lossRes, tf_dict)
            self.total_loss.append(loss_t)
            self.loss_data.append(loss_d)
            self.loss_res.append(loss_p)
            
            # Print
            if it % 500 == 0:
                elapsed = time.time() - start_time
                loss_t = self.sess.run(self.loss, tf_dict)
                loss_d = self.sess.run(self.lossData, tf_dict)
                loss_p = self.sess.run(self.lossRes, tf_dict)
                print('It: %d, Loss: %.3e, Time: %.2f' % 
                      (it, loss_t, elapsed))
                print('Data Loss: %.3e' % 
                      (loss_d))
                #start_time = time.time()
            if it % 1 == 0:
                loss_seq.append(loss_t)
        return loss_seq
              
    def predict(self, t_star):
        tf.set_random_seed(SEED)
        np.random.seed(SEED)
        tf_dict = {self.t_tf: t_star}
        S_l = self.sess.run(self.s_list, tf_dict)
        V_l = self.sess.run(self.v_list, tf_dict)
        E_l = self.sess.run(self.e_list, tf_dict)
        I1_l = self.sess.run(self.i1_list, tf_dict)
        I2_l = self.sess.run(self.i2_list, tf_dict)
        I3_l = self.sess.run(self.i3_list, tf_dict)
        R_l = self.sess.run(self.r_list, tf_dict)
        D_l = self.sess.run(self.d_list, tf_dict)
        return S_l, V_l, E_l, I1_l, I2_l, I3_l, R_l, D_l

# %%
def data_preprocess(data, lb, ub, npoints):
    tdat = data.reindex(index=data.index[::1])
    s_real = tdat["S"]
    v_real = tdat["V"]
    e_real = tdat["E"]
    i1_real = tdat["I1"]
    i2_real = tdat["I2"]
    i3_real = tdat["I3"]
    r_real = tdat["R"]
    d_real = tdat["D"]

    S_s =np.array(s_real.values).reshape((-1,1))
    V_s =np.array(v_real.values).reshape((-1,1))
    E_s =np.array(e_real.values).reshape((-1,1))
    I1_s =np.array(i1_real.values).reshape((-1,1))
    I2_s =np.array(i2_real.values).reshape((-1,1))
    I3_s =np.array(i3_real.values).reshape((-1,1))
    R_s =np.array(r_real.values).reshape((-1,1))
    D_s =np.array(d_real.values).reshape((-1,1))
    
    S = S_s[lb:ub,:]
    V = V_s[lb:ub,:]
    E = E_s[lb:ub,:]
    I1 = I1_s[lb:ub,:]
    I2 = I2_s[lb:ub,:]
    I3 = I3_s[lb:ub,:]
    R = R_s[lb:ub,:]
    D = D_s[lb:ub,:]
    
    tf.set_random_seed(SEED)
    np.random.seed(SEED)
    length = int(ub-lb)
    T = np.arange(0, length)
    S_spline = CubicSpline(T, S)
    V_spline = CubicSpline(T, V)
    E_spline = CubicSpline(T, E)
    I1_spline = CubicSpline(T, I1)
    I2_spline = CubicSpline(T, I2)
    I3_spline = CubicSpline(T, I3)
    R_spline = CubicSpline(T, R)
    D_spline = CubicSpline(T, D)
    
    # convert real data to match the desired data frequency 
    tt = np.linspace(0, length, npoints)
    t_s, S_s, V_s, E_s, I1_s, I2_s, I3_s, R_s, D_s = tt, S_spline(tt), V_spline(tt), E_spline(tt), I1_spline(tt), I2_spline(tt), I3_spline(tt), R_spline(tt), D_spline(tt)

    N_t = S_s + V_s + E_s + I1_s + I2_s + I3_s + R_s + D_s
    
    t_aug = t_s.reshape((-1,1))
    S_aug = S_s.reshape((-1,1))/N_t
    V_aug = V_s.reshape((-1,1))/N_t
    E_aug = E_s.reshape((-1,1))/N_t
    I1_aug = I1_s.reshape((-1,1))/N_t
    I2_aug = I2_s.reshape((-1,1))/N_t
    I3_aug = I3_s.reshape((-1,1))/N_t
    R_aug = R_s.reshape((-1,1))/N_t
    D_aug = D_s.reshape((-1,1))/N_t
    
    return S_aug, V_aug, E_aug, I1_aug, I2_aug, I3_aug, R_aug, D_aug, t_aug

# %%
# process the real data into more data points
tf.set_random_seed(SEED)
np.random.seed(SEED)
SS, VV, EE, I1I, I2I, I3I, RR, DD, T = data_preprocess(data, lb, ub, npoints)

np.random.seed(SEED)
dW1 = np.random.normal(size=(npoints, 1))    
dW2 = np.random.normal(size=(npoints, 1))  
dW3 = np.random.normal(size=(npoints, 1))  
dW4 = np.random.normal(size=(npoints, 1))  
dW5 = np.random.normal(size=(npoints, 1))  
dW6 = np.random.normal(size=(npoints, 1))  
dW7 = np.random.normal(size=(npoints, 1))  
dW8 = np.random.normal(size=(npoints, 1))  

tf.set_random_seed(SEED)
np.random.seed(SEED)
model = SIR(SS, VV, EE, I1I, I2I, I3I, RR, DD, T, layers, alpha1, alpha2, dW1, dW2, dW3, dW4, dW5, dW6, dW7, dW8, n_mc)

tf.set_random_seed(SEED)
np.random.seed(SEED)
total_loss = model.train(epochs)  #for Adam
S_l, V_l, E_l, I1_l, I2_l, I3_l, R_l, D_l = model.predict(T)
# Out:
# Device mapping: no known devices.
# Variable: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_15: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_15/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_15/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_21: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_21/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_21/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_1/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_1: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_2/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_2: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_27: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_27/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_27/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_3/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_3/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_3: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_29: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_29/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_29/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_4/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_4/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_4: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_31: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_31/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_31/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_5/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_5/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_5: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_32: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_32/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_32/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_33: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_33/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_33/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_6/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_6/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_6: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_34: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_34/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_34/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_35: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_35/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_35/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_7/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_7/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_7: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_36: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_36/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_36/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_37: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_37/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_37/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_8/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_8/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_8: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_38: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_38/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_38/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_39: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_39/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_39/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_9/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_9/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_9: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_40: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_40/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_40/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_41: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_41/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_41/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_10/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_10/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_10: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_42: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_42/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_42/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_43: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_43/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_43/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_11/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_11/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_11: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_44: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_44/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_44/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_45: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_45/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_45/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_12/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_12/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_12: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_46: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_46/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_46/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_47: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_47/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_47/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_13/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_13/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_13: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_48: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_48/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_48/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_49: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_49/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_49/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_14/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_14/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_14: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_50: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_50/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_50/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_51: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_51/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_51/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_15/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_15/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_15: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_52: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_52/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_52/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_53: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_53/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_53/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_16/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_16/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_16: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_54: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_54/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_54/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_55: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_55/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_55/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_17/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_17/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_17: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_56: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_56/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_56/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_57: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_57/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_57/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_18/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_18/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_18: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_58: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_58/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_58/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_59: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_59/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_59/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_19/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_19/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_19: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_60: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_60/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_60/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_61: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_61/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_61/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_20/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_20/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_20: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_62: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_62/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_62/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_63: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_63/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_63/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_21/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_21/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_21: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_64: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_64/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_64/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_65: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_65/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_65/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_22/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_22/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_22: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_66: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_66/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_66/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_67: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_67/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_67/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_23/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_23/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_23: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_68: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_68/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_68/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_69: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_69/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_69/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_24/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_24/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_24: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_70: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_70/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_70/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_71: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_71/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_71/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_25/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_25/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_25: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_72: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_72/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_72/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_73: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_73/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_73/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_26/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_26/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_26: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_74: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_74/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_74/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_75: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_75/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_75/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_27/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_27/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_27: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_76: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_76/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_76/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_77: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_77/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_77/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_28/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_28/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_28: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_78: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_78/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_78/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_79: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_79/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_79/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_29/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_29/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_29: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_80: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_80/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_80/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_81: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_81/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_81/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_30/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_30/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_30: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_82: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_82/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_82/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_83: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_83/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_83/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_31/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_31/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_31: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_84: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_84/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_84/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_85: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_85/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_85/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_32/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_32/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_32: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_86: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_86/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_86/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_87: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_87/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_87/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_33/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_33/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_33: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_88: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_88/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_88/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_89: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_89/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_89/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_34/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_34/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_34: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_90: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_90/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_90/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_91: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_91/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_91/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_35/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_35/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_35: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_92: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_92/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_92/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_93: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_93/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_93/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_36/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_36/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_36: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_94: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_94/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_94/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_95: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_95/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_95/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_37/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_37/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_37: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_96: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_96/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_96/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_97: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_97/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_97/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_38/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_38/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_38: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_98: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_98/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_98/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_99: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_99/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_99/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_39/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_39/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_39: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_100: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_100/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_100/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_101: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_101/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_101/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_40/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_40/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_40: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_102: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_102/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_102/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_103: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_103/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_103/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_41/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_41/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_41: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_104: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_104/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_104/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_105: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_105/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_105/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_42/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_42/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_42: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_106: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_106/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_106/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_107: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_107/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_107/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_43/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_43/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_43: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_108: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_108/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_108/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_109: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_109/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_109/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_44/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_44/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_44: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_110: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_110/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_110/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_111: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_111/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_111/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_45/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_45/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_45: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_112: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_112/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_112/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_113: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_113/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_113/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_46/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_46/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_46: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_114: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_114/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_114/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_115: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_115/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_115/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_47/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_47/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_47: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_116: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_116/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_116/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_117: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_117/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_117/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_48/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_48/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_48: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_118: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_118/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_118/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_119: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_119/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_119/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_49/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_49/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_49: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_120: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_120/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_120/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_121: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_121/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_121/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_50/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_50/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_50: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_122: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_122/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_122/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_123: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_123/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_123/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_51/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_51/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_51: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_124: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_124/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_124/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_125: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_125/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_125/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_52/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_52/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_52: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_126: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_126/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_126/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_127: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_127/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_127/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_53/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_53/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_53: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_128: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_128/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_128/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_129: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_129/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_129/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_54/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_54/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_54: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_130: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_130/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_130/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_131: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_131/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_131/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_55/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_55/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_55: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_132: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_132/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_132/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_133: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_133/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_133/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_56/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_56/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_56: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_134: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_134/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_134/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_135: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_135/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_135/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_57/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_57/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_57: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_136: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_136/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_136/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_137: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_137/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_137/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_58/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_58/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_58: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_138: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_138/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_138/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_139: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_139/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_139/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_59/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_59/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_59: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_140: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_140/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_140/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_141: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_141/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_141/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_60/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_60/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_60: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_142: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_142/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_142/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_143: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_143/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_143/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_61/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_61/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# truncated_normal_61: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_144: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_144/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_144/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_145: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_145/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# gradients/strided_slice_307_grad/StridedSliceGrad/strides: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/strided_slice_308_grad/StridedSliceGrad/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/strided_slice_308_grad/StridedSliceGrad/end: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/strided_slice_308_grad/StridedSliceGrad/strides: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_26/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_27/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_27/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_28/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_29/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_29/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_30/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_31/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_31/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/learning_rate: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/beta1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/beta2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Adam/epsilon: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# It: 0, Loss: 1.687e+00, Time: 4.52
# Data Loss: 1.653e+00
# It: 500, Loss: 1.670e+00, Time: 9.58
# Data Loss: 1.638e+00
# It: 1000, Loss: 1.650e+00, Time: 14.47
# Data Loss: 1.618e+00
# It: 1500, Loss: 1.622e+00, Time: 19.35
# Data Loss: 1.592e+00
# It: 2000, Loss: 1.586e+00, Time: 24.44
# Data Loss: 1.557e+00
# It: 2500, Loss: 1.541e+00, Time: 29.37
# Data Loss: 1.514e+00
# It: 3000, Loss: 1.487e+00, Time: 34.25
# Data Loss: 1.462e+00
# It: 3500, Loss: 1.424e+00, Time: 39.24
# Data Loss: 1.400e+00
# It: 4000, Loss: 1.351e+00, Time: 44.15
# Data Loss: 1.329e+00
# It: 4500, Loss: 1.269e+00, Time: 49.13
# Data Loss: 1.250e+00
# It: 5000, Loss: 1.179e+00, Time: 54.15
# Data Loss: 1.163e+00
# It: 5500, Loss: 1.083e+00, Time: 59.03
# Data Loss: 1.069e+00
# It: 6000, Loss: 9.816e-01, Time: 63.91
# Data Loss: 9.701e-01
# It: 6500, Loss: 8.778e-01, Time: 68.87
# Data Loss: 8.685e-01
# It: 7000, Loss: 7.739e-01, Time: 73.79
# Data Loss: 7.666e-01
# It: 7500, Loss: 6.726e-01, Time: 78.67
# Data Loss: 6.670e-01
# It: 8000, Loss: 5.761e-01, Time: 83.61
# Data Loss: 5.719e-01
# It: 8500, Loss: 4.865e-01, Time: 88.52
# Data Loss: 4.835e-01
# It: 9000, Loss: 4.052e-01, Time: 93.49
# Data Loss: 4.031e-01
# It: 9500, Loss: 3.333e-01, Time: 98.37
# Data Loss: 3.318e-01
# It: 10000, Loss: 2.709e-01, Time: 103.28
# Data Loss: 2.699e-01
# It: 10500, Loss: 2.179e-01, Time: 108.18
# Data Loss: 2.172e-01
# It: 11000, Loss: 1.737e-01, Time: 112.95
# Data Loss: 1.732e-01
# It: 11500, Loss: 1.374e-01, Time: 117.90
# Data Loss: 1.371e-01
# It: 12000, Loss: 1.081e-01, Time: 122.86
# Data Loss: 1.079e-01
# It: 12500, Loss: 8.470e-02, Time: 127.76
# Data Loss: 8.459e-02
# It: 13000, Loss: 6.631e-02, Time: 132.60
# Data Loss: 6.624e-02
# It: 13500, Loss: 5.194e-02, Time: 137.45
# Data Loss: 5.189e-02
# It: 14000, Loss: 4.077e-02, Time: 142.35
# Data Loss: 4.074e-02
# It: 14500, Loss: 3.213e-02, Time: 147.25
# Data Loss: 3.211e-02
# It: 15000, Loss: 2.546e-02, Time: 152.27
# Data Loss: 2.545e-02
# It: 15500, Loss: 2.029e-02, Time: 157.21
# Data Loss: 2.028e-02
# It: 16000, Loss: 1.624e-02, Time: 162.04
# Data Loss: 1.624e-02
# It: 16500, Loss: 1.302e-02, Time: 166.91
# Data Loss: 1.302e-02
# It: 17000, Loss: 1.043e-02, Time: 171.88
# Data Loss: 1.042e-02
# It: 17500, Loss: 8.310e-03, Time: 176.76
# Data Loss: 8.309e-03
# It: 18000, Loss: 6.590e-03, Time: 181.73
# Data Loss: 6.589e-03
# It: 18500, Loss: 5.200e-03, Time: 186.70
# Data Loss: 5.199e-03
# It: 19000, Loss: 4.087e-03, Time: 191.66
# Data Loss: 4.087e-03
# It: 19500, Loss: 3.205e-03, Time: 196.54
# Data Loss: 3.204e-03
# It: 20000, Loss: 2.509e-03, Time: 201.53
# Data Loss: 2.509e-03
# It: 20500, Loss: 1.965e-03, Time: 206.33
# Data Loss: 1.964e-03
# It: 21000, Loss: 1.540e-03, Time: 211.13
# Data Loss: 1.540e-03
# It: 21500, Loss: 1.211e-03, Time: 215.98
# Data Loss: 1.211e-03
# It: 22000, Loss: 9.557e-04, Time: 220.76
# Data Loss: 9.557e-04
# It: 22500, Loss: 7.585e-04, Time: 225.45
# Data Loss: 7.584e-04
# It: 23000, Loss: 6.061e-04, Time: 230.15
# Data Loss: 6.061e-04
# It: 23500, Loss: 4.884e-04, Time: 234.87
# Data Loss: 4.883e-04
# It: 24000, Loss: 3.972e-04, Time: 239.53
# Data Loss: 3.972e-04
# It: 24500, Loss: 3.264e-04, Time: 244.33
# Data Loss: 3.264e-04
# It: 25000, Loss: 2.712e-04, Time: 249.04
# Data Loss: 2.712e-04
# It: 25500, Loss: 2.278e-04, Time: 253.77
# Data Loss: 2.278e-04
# It: 26000, Loss: 1.933e-04, Time: 258.59
# Data Loss: 1.933e-04
# It: 26500, Loss: 1.656e-04, Time: 263.42
# Data Loss: 1.656e-04
# It: 27000, Loss: 1.429e-04, Time: 268.24
# Data Loss: 1.429e-04
# It: 27500, Loss: 1.241e-04, Time: 272.96
# Data Loss: 1.241e-04
# It: 28000, Loss: 1.083e-04, Time: 277.82
# Data Loss: 1.083e-04
# It: 28500, Loss: 9.509e-05, Time: 282.59
# Data Loss: 9.508e-05
# It: 29000, Loss: 8.387e-05, Time: 287.46
# Data Loss: 8.385e-05
# It: 29500, Loss: 7.437e-05, Time: 292.18
# Data Loss: 7.436e-05
# It: 30000, Loss: 6.639e-05, Time: 296.93
# Data Loss: 6.638e-05
# It: 30500, Loss: 5.977e-05, Time: 301.70
# Data Loss: 5.975e-05
# It: 31000, Loss: 5.432e-05, Time: 306.46
# Data Loss: 5.431e-05
# It: 31500, Loss: 4.990e-05, Time: 311.18
# Data Loss: 4.989e-05
# It: 32000, Loss: 4.633e-05, Time: 315.95
# Data Loss: 4.632e-05
# It: 32500, Loss: 4.344e-05, Time: 320.71
# Data Loss: 4.343e-05
# It: 33000, Loss: 4.111e-05, Time: 325.50
# Data Loss: 4.110e-05
# It: 33500, Loss: 3.922e-05, Time: 330.21
# Data Loss: 3.921e-05
# It: 34000, Loss: 3.769e-05, Time: 334.95
# Data Loss: 3.768e-05
# It: 34500, Loss: 3.643e-05, Time: 339.69
# Data Loss: 3.642e-05
# It: 35000, Loss: 3.540e-05, Time: 344.50
# Data Loss: 3.539e-05
# It: 35500, Loss: 3.454e-05, Time: 349.21
# Data Loss: 3.453e-05
# It: 36000, Loss: 3.383e-05, Time: 354.13
# Data Loss: 3.382e-05
# It: 36500, Loss: 3.324e-05, Time: 358.92
# Data Loss: 3.323e-05
# It: 37000, Loss: 3.275e-05, Time: 363.62
# Data Loss: 3.274e-05
# It: 37500, Loss: 3.233e-05, Time: 368.40
# Data Loss: 3.233e-05
# It: 38000, Loss: 3.198e-05, Time: 373.23
# Data Loss: 3.197e-05
# It: 38500, Loss: 3.168e-05, Time: 378.03
# Data Loss: 3.167e-05
# It: 39000, Loss: 3.141e-05, Time: 382.82
# Data Loss: 3.140e-05
# It: 39500, Loss: 3.117e-05, Time: 387.47
# Data Loss: 3.116e-05
# It: 40000, Loss: 3.094e-05, Time: 392.25
# Data Loss: 3.094e-05
# It: 40500, Loss: 3.073e-05, Time: 397.03
# Data Loss: 3.073e-05
# It: 41000, Loss: 3.052e-05, Time: 401.94
# Data Loss: 3.051e-05
# It: 41500, Loss: 3.030e-05, Time: 406.68
# Data Loss: 3.030e-05
# It: 42000, Loss: 3.007e-05, Time: 411.43
# Data Loss: 3.006e-05
# It: 42500, Loss: 2.980e-05, Time: 416.18
# Data Loss: 2.980e-05
# It: 43000, Loss: 2.949e-05, Time: 420.94
# Data Loss: 2.949e-05
# It: 43500, Loss: 2.913e-05, Time: 425.79
# Data Loss: 2.912e-05
# It: 44000, Loss: 2.868e-05, Time: 430.50
# Data Loss: 2.868e-05
# It: 44500, Loss: 2.817e-05, Time: 435.34
# Data Loss: 2.817e-05
# It: 45000, Loss: 2.760e-05, Time: 440.06
# Data Loss: 2.760e-05
# It: 45500, Loss: 2.700e-05, Time: 444.79
# Data Loss: 2.700e-05
# It: 46000, Loss: 2.640e-05, Time: 449.55
# Data Loss: 2.639e-05
# It: 46500, Loss: 2.580e-05, Time: 454.33
# Data Loss: 2.580e-05
# It: 47000, Loss: 2.523e-05, Time: 459.14
# Data Loss: 2.523e-05
# It: 47500, Loss: 2.469e-05, Time: 463.85
# Data Loss: 2.468e-05
# It: 48000, Loss: 2.416e-05, Time: 468.55
# Data Loss: 2.415e-05
# It: 48500, Loss: 2.364e-05, Time: 473.23
# Data Loss: 2.363e-05
# It: 49000, Loss: 2.312e-05, Time: 478.08
# Data Loss: 2.312e-05
# It: 49500, Loss: 2.260e-05, Time: 482.81
# Data Loss: 2.260e-05
# It: 50000, Loss: 2.208e-05, Time: 487.51
# Data Loss: 2.208e-05
# It: 50500, Loss: 2.156e-05, Time: 492.24
# Data Loss: 2.156e-05
# It: 51000, Loss: 2.105e-05, Time: 496.98
# Data Loss: 2.105e-05
# It: 51500, Loss: 2.054e-05, Time: 501.74
# Data Loss: 2.054e-05
# It: 52000, Loss: 2.004e-05, Time: 506.49
# Data Loss: 2.003e-05
# It: 52500, Loss: 1.955e-05, Time: 511.28
# Data Loss: 1.955e-05
# It: 53000, Loss: 1.907e-05, Time: 516.13
# Data Loss: 1.907e-05
# It: 53500, Loss: 1.862e-05, Time: 520.91
# Data Loss: 1.862e-05
# It: 54000, Loss: 1.818e-05, Time: 525.80
# Data Loss: 1.818e-05
# It: 54500, Loss: 1.776e-05, Time: 530.54
# Data Loss: 1.776e-05
# It: 55000, Loss: 1.735e-05, Time: 535.53
# Data Loss: 1.735e-05
# It: 55500, Loss: 1.696e-05, Time: 540.31
# Data Loss: 1.696e-05
# It: 56000, Loss: 1.658e-05, Time: 545.06
# Data Loss: 1.658e-05
# It: 56500, Loss: 1.621e-05, Time: 549.76
# Data Loss: 1.621e-05
# It: 57000, Loss: 1.586e-05, Time: 554.56
# Data Loss: 1.585e-05
# It: 57500, Loss: 1.551e-05, Time: 559.32
# Data Loss: 1.551e-05
# It: 58000, Loss: 1.518e-05, Time: 564.09
# Data Loss: 1.518e-05
# It: 58500, Loss: 1.486e-05, Time: 568.78
# Data Loss: 1.485e-05
# It: 59000, Loss: 1.455e-05, Time: 573.54
# Data Loss: 1.454e-05
# It: 59500, Loss: 1.425e-05, Time: 578.31
# Data Loss: 1.425e-05
# It: 60000, Loss: 1.396e-05, Time: 583.10
# Data Loss: 1.396e-05
# It: 60500, Loss: 1.369e-05, Time: 587.93
# Data Loss: 1.369e-05
# It: 61000, Loss: 1.343e-05, Time: 592.64
# Data Loss: 1.343e-05
# It: 61500, Loss: 1.319e-05, Time: 597.31
# Data Loss: 1.319e-05
# It: 62000, Loss: 1.296e-05, Time: 602.13
# Data Loss: 1.296e-05
# It: 62500, Loss: 1.274e-05, Time: 606.89
# Data Loss: 1.274e-05
# It: 63000, Loss: 1.254e-05, Time: 611.65
# Data Loss: 1.254e-05
# It: 63500, Loss: 1.236e-05, Time: 616.30
# Data Loss: 1.235e-05
# It: 64000, Loss: 1.218e-05, Time: 620.97
# Data Loss: 1.218e-05
# It: 64500, Loss: 1.202e-05, Time: 625.75
# Data Loss: 1.202e-05
# It: 65000, Loss: 1.187e-05, Time: 630.54
# Data Loss: 1.187e-05
# It: 65500, Loss: 1.173e-05, Time: 635.29
# Data Loss: 1.173e-05
# It: 66000, Loss: 1.160e-05, Time: 640.11
# Data Loss: 1.160e-05
# It: 66500, Loss: 1.148e-05, Time: 644.86
# Data Loss: 1.148e-05
# It: 67000, Loss: 1.137e-05, Time: 649.65
# Data Loss: 1.137e-05
# It: 67500, Loss: 1.126e-05, Time: 654.40
# Data Loss: 1.126e-05
# It: 68000, Loss: 1.116e-05, Time: 659.06
# Data Loss: 1.116e-05
# It: 68500, Loss: 1.106e-05, Time: 663.74
# Data Loss: 1.106e-05
# It: 69000, Loss: 1.097e-05, Time: 668.56
# Data Loss: 1.097e-05
# It: 69500, Loss: 1.088e-05, Time: 673.28
# Data Loss: 1.088e-05
# It: 70000, Loss: 1.079e-05, Time: 678.06
# Data Loss: 1.079e-05
# It: 70500, Loss: 1.070e-05, Time: 682.79
# Data Loss: 1.070e-05
# It: 71000, Loss: 1.061e-05, Time: 687.44
# Data Loss: 1.061e-05
# It: 71500, Loss: 1.052e-05, Time: 692.14
# Data Loss: 1.052e-05
# It: 72000, Loss: 1.043e-05, Time: 696.81
# Data Loss: 1.042e-05
# It: 72500, Loss: 1.033e-05, Time: 701.47
# Data Loss: 1.033e-05
# It: 73000, Loss: 1.024e-05, Time: 706.22
# Data Loss: 1.023e-05
# It: 73500, Loss: 1.014e-05, Time: 710.97
# Data Loss: 1.014e-05
# It: 74000, Loss: 1.004e-05, Time: 715.69
# Data Loss: 1.004e-05
# It: 74500, Loss: 9.940e-06, Time: 720.37
# Data Loss: 9.938e-06
# It: 75000, Loss: 9.837e-06, Time: 725.09
# Data Loss: 9.836e-06
# It: 75500, Loss: 9.734e-06, Time: 729.80
# Data Loss: 9.733e-06
# It: 76000, Loss: 9.630e-06, Time: 734.53
# Data Loss: 9.629e-06
# It: 76500, Loss: 9.526e-06, Time: 739.35
# Data Loss: 9.524e-06
# It: 77000, Loss: 9.422e-06, Time: 744.08
# Data Loss: 9.420e-06
# It: 77500, Loss: 9.318e-06, Time: 748.80
# Data Loss: 9.316e-06
# It: 78000, Loss: 9.215e-06, Time: 753.50
# Data Loss: 9.213e-06
# It: 78500, Loss: 9.113e-06, Time: 758.28
# Data Loss: 9.112e-06
# It: 79000, Loss: 9.013e-06, Time: 763.22
# Data Loss: 9.012e-06
# It: 79500, Loss: 8.915e-06, Time: 768.02
# Data Loss: 8.913e-06
# It: 80000, Loss: 8.819e-06, Time: 772.95
# Data Loss: 8.817e-06
# It: 80500, Loss: 8.725e-06, Time: 777.67
# Data Loss: 8.723e-06
# It: 81000, Loss: 8.632e-06, Time: 782.31
# Data Loss: 8.630e-06
# It: 81500, Loss: 8.540e-06, Time: 786.97
# Data Loss: 8.539e-06
# It: 82000, Loss: 8.451e-06, Time: 791.72
# Data Loss: 8.449e-06
# It: 82500, Loss: 8.362e-06, Time: 796.53
# Data Loss: 8.360e-06
# It: 83000, Loss: 8.274e-06, Time: 801.27
# Data Loss: 8.272e-06
# It: 83500, Loss: 8.187e-06, Time: 805.99
# Data Loss: 8.185e-06
# It: 84000, Loss: 8.100e-06, Time: 810.72
# Data Loss: 8.098e-06
# It: 84500, Loss: 8.014e-06, Time: 815.45
# Data Loss: 8.012e-06
# It: 85000, Loss: 7.928e-06, Time: 819.91
# Data Loss: 7.927e-06
# It: 85500, Loss: 7.843e-06, Time: 824.29
# Data Loss: 7.841e-06
# It: 86000, Loss: 7.758e-06, Time: 828.73
# Data Loss: 7.756e-06
# It: 86500, Loss: 7.673e-06, Time: 833.14
# Data Loss: 7.671e-06
# It: 87000, Loss: 7.588e-06, Time: 837.45
# Data Loss: 7.586e-06
# It: 87500, Loss: 7.504e-06, Time: 841.72
# Data Loss: 7.502e-06
# It: 88000, Loss: 7.420e-06, Time: 846.01
# Data Loss: 7.418e-06
# It: 88500, Loss: 7.336e-06, Time: 850.24
# Data Loss: 7.335e-06
# It: 89000, Loss: 7.254e-06, Time: 854.59
# Data Loss: 7.252e-06
# It: 89500, Loss: 7.173e-06, Time: 858.98
# Data Loss: 7.171e-06
# It: 90000, Loss: 7.093e-06, Time: 863.33
# Data Loss: 7.092e-06
# It: 90500, Loss: 7.015e-06, Time: 867.67
# Data Loss: 7.013e-06
# It: 91000, Loss: 6.939e-06, Time: 872.04
# Data Loss: 6.937e-06
# It: 91500, Loss: 6.864e-06, Time: 876.51
# Data Loss: 6.863e-06
# It: 92000, Loss: 6.792e-06, Time: 880.84
# Data Loss: 6.791e-06
# It: 92500, Loss: 6.722e-06, Time: 885.21
# Data Loss: 6.721e-06
# It: 93000, Loss: 6.655e-06, Time: 889.60
# Data Loss: 6.653e-06
# It: 93500, Loss: 6.590e-06, Time: 894.04
# Data Loss: 6.588e-06
# It: 94000, Loss: 6.527e-06, Time: 898.63
# Data Loss: 6.526e-06
# It: 94500, Loss: 6.467e-06, Time: 903.10
# Data Loss: 6.465e-06
# It: 95000, Loss: 6.409e-06, Time: 907.59
# Data Loss: 6.408e-06
# It: 95500, Loss: 6.354e-06, Time: 912.04
# Data Loss: 6.353e-06
# It: 96000, Loss: 6.302e-06, Time: 916.50
# Data Loss: 6.300e-06
# It: 96500, Loss: 6.252e-06, Time: 920.83
# Data Loss: 6.250e-06
# It: 97000, Loss: 6.204e-06, Time: 925.16
# Data Loss: 6.203e-06
# It: 97500, Loss: 6.159e-06, Time: 929.70
# Data Loss: 6.158e-06
# It: 98000, Loss: 6.116e-06, Time: 934.34
# Data Loss: 6.115e-06
# It: 98500, Loss: 6.076e-06, Time: 939.03
# Data Loss: 6.074e-06
# It: 99000, Loss: 6.037e-06, Time: 943.69
# Data Loss: 6.035e-06
# It: 99500, Loss: 6.001e-06, Time: 948.32
# Data Loss: 5.999e-06

# %%
v1 =np.array(S_l)
v2 =np.array(V_l)
v3 =np.array(E_l)
v4 =np.array(I1_l)
v5 =np.array(I2_l)
v6 =np.array(I3_l)
v7 =np.array(R_l)
v8 =np.array(D_l)

S_pred_m =np.mean(v1, axis=0)
V_pred_m =np.mean(v2, axis=0)
E_pred_m =np.mean(v3, axis=0)
I1_pred_m =np.mean(v4, axis=0)
I2_pred_m =np.mean(v5, axis=0)
I3_pred_m =np.mean(v6, axis=0)
R_pred_m =np.mean(v7, axis=0)
D_pred_m =np.mean(v8, axis=0)


alpha_v1 = model.sess.run(model.alpha)
sigma_v1 = model.sess.run(model.sigma)
beta1_v1 = model.sess.run(model.beta1)
beta2_v1 = model.sess.run(model.beta2)
beta3_v1 = model.sess.run(model.beta3)
delta1_v1= model.sess.run(model.delta1)
delta2_v1 = model.sess.run(model.delta2)
delta3_v1 = model.sess.run(model.delta3)
mu_v1 = model.sess.run(model.mu)
gamma_v1 = model.sess.run(model.gamma)
p1_v1 = model.sess.run(model.p1)
p2_v1 = model.sess.run(model.p2)
sigma1_v1 = model.sess.run(model.sigma1)
sigma2_v1 = model.sess.run(model.sigma2)
sigma3_v1 = model.sess.run(model.sigma3)
sigma4_v1 = model.sess.run(model.sigma4)
sigma5_v1 = model.sess.run(model.sigma5)
sigma6_v1 = model.sess.run(model.sigma6)
sigma7_v1 = model.sess.run(model.sigma7)
sigma8_v1 = model.sess.run(model.sigma8)


alpha = round(alpha_v1, 5)
sigma = round(sigma_v1, 5)
beta1 = round(beta1_v1, 5)
beta2 = round(beta2_v1, 5)
beta3 = round(beta3_v1, 5)
delta1 = round(delta1_v1, 5)
delta2 = round(delta2_v1, 5)
delta3 = round(delta3_v1, 5)
mu = round(mu_v1, 5)
gamma = round(gamma_v1, 5)
p1 = round(p1_v1, 5)
p2 = round(p2_v1, 5)
sigma1 = round(sigma1_v1, 5)
sigma2 = round(sigma2_v1, 5)
sigma3 = round(sigma3_v1, 5)
sigma4 = round(sigma4_v1, 5)
sigma5 = round(sigma5_v1, 5)
sigma6 = round(sigma6_v1, 5)
sigma7 = round(sigma7_v1, 5)
sigma8 = round(sigma8_v1, 5)

fig2, ax2 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax2.plot(total_loss)

# %% [markdown]
# Calibrated Parameter Results

# %%
print('alpha', alpha)
print('sigma',sigma) 
print('beta1',beta1) 
print('beta2',beta2)
print('beta3',beta3)
print('delta1',delta1)
print('delta2',delta2)
print('delta3',delta3)
print('mu',mu)
print('gamma',gamma)
print('p1',p1)
print('p2',p2)
print('sigma1 S',sigma1) 
print('sigma2 V',sigma2)
print('sigma3 E',sigma3)
print('sigma4 I1',sigma4)
print('sigma5 I2',sigma5)
print('sigma6 I3',sigma6)
print('sigma7 R',sigma7)
print('sigma8 D',sigma8)
# Out:
# alpha 0.00171
# sigma 0.06353
# beta1 0.28121
# beta2 0.15838
# beta3 0.03881
# delta1 0.28505
# delta2 0.28269
# delta3 0.14206
# mu 0.00492
# gamma 0.30959
# p1 0.02089
# p2 0.14311
# sigma1 S 0.09278
# sigma2 V 0.03863
# sigma3 E 0.07516
# sigma4 I1 0.06305
# sigma5 I2 0.07877
# sigma6 I3 0.06125
# sigma7 R 0.06111
# sigma8 D 0.06199

# %% [markdown]
# Error matrix
# - RMSE
# - MAPE

# %%
##Calculate the error metrics for stochastic for Infected
S_test_pred = S_pred_m.reshape(-1,) 
S_test_actual = SS.reshape(-1,)

S_rmse =np.sqrt(mean_squared_error(S_test_actual, S_test_pred))
S_mape =np.linalg.norm((S_test_pred-S_test_actual),2)/np.linalg.norm(S_test_actual, 2)   

print('S_RMSE',S_rmse)
print('S_MAPE',S_mape)

V_test_pred = V_pred_m.reshape(-1,) 
V_test_actual = VV.reshape(-1,)

V_rmse =np.sqrt(mean_squared_error(V_test_actual, V_test_pred))
V_mape =np.linalg.norm((V_test_pred-V_test_actual),2)/np.linalg.norm(V_test_actual, 2)   

print('V_RMSE',V_rmse)
print('V_MAPE',V_mape)

E_test_pred = E_pred_m.reshape(-1,) 
E_test_actual = EE.reshape(-1,)

E_rmse =np.sqrt(mean_squared_error(E_test_actual, E_test_pred))
E_mape =np.linalg.norm((E_test_pred - E_test_actual),2)/np.linalg.norm(E_test_actual, 2)   

print('E_RMSE',E_rmse)
print('E_MAPE',E_mape)

I1_test_pred = I1_pred_m.reshape(-1,) 
I1_test_actual = I1I.reshape(-1,)

I1_rmse =np.sqrt(mean_squared_error(I1_test_actual, I1_test_pred))
I1_mape =np.linalg.norm((I1_test_pred-I1_test_actual),2)/np.linalg.norm(I1_test_actual, 2)   

print('I1_RMSE',I1_rmse)
print('I1_MAPE',I1_mape)

I2_test_pred = I2_pred_m.reshape(-1,) 
I2_test_actual = I2I.reshape(-1,)

I2_rmse =np.sqrt(mean_squared_error(I2_test_actual, I2_test_pred))
I2_mape =np.linalg.norm((I2_test_pred-I2_test_actual),2)/np.linalg.norm(I2_test_actual, 2)   

print('I2_RMSE',I2_rmse)
print('I2_MAPE',I2_mape)

I3_test_pred = I3_pred_m.reshape(-1,) 
I3_test_actual = I3I.reshape(-1,)

I3_rmse =np.sqrt(mean_squared_error(I3_test_actual, I3_test_pred))
I3_mape =np.linalg.norm((I3_test_pred-I3_test_actual),2)/np.linalg.norm(I3_test_actual, 2)   

print('I3_RMSE',I3_rmse)
print('I3_MAPE',I3_mape)

R_test_pred = R_pred_m.reshape(-1,) 
R_test_actual = RR.reshape(-1,)

R_rmse =np.sqrt(mean_squared_error(R_test_actual, R_test_pred))
R_mape =np.linalg.norm((R_test_pred - R_test_actual),2)/np.linalg.norm(R_test_actual, 2)   

print('R_RMSE', R_rmse)
print('R_MAPE', R_mape)

D_test_pred = D_pred_m.reshape(-1,) 
D_test_actual = DD.reshape(-1,)

D_rmse =np.sqrt(mean_squared_error(D_test_actual, D_test_pred))
D_mape =np.linalg.norm((D_test_pred-D_test_actual),2)/np.linalg.norm(D_test_actual, 2)   

print('D_RMSE',D_rmse)
print('D_MAPE',D_mape)

total_rmse = S_rmse + V_rmse + E_rmse + I1_rmse + I2_rmse + I3_rmse + R_rmse + D_rmse
total_mape = S_mape + V_mape + E_mape + I1_mape + I2_mape + I3_mape + R_mape + D_mape
print('TOTAL_RMSE', total_rmse)
print('TOTAL_MAPE', total_mape)
# Out:
# S_RMSE 0.0012325168770198193
# S_MAPE 0.006744837410594592
# V_RMSE 0.0001744073382705337
# V_MAPE 0.00022174387706036029
# E_RMSE 0.0020744376265033056
# E_MAPE 0.1926941154835765
# I1_RMSE 0.000206789023316019
# I1_MAPE 0.10784614359747721
# I2_RMSE 8.408613955537776e-05
# I2_MAPE 1.6020530520795135
# I3_RMSE 8.144312170089755e-05
# I3_MAPE 7.879473811244067
# R_RMSE 0.00017564839837290642
# R_MAPE 0.00936559962041043
# D_RMSE 0.00015533316197987928
# D_MAPE 0.7194492488284354
# TOTAL_RMSE 0.004184661686718738
# TOTAL_MAPE 10.517848552141137

# %%
st ='2021-12-03'
ed ='2021-12-23'
date_begin = dt.date(2021, 12, 3)
date_end = date_begin + dt.timedelta(days=ub) 
delt = dt.timedelta(days = ub/npoints)
dates = mpl.dates.drange(date_begin, date_end, delt)

# %%
lims = (np.datetime64(st), np.datetime64(ed))

fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,SS, '--g')
ax1.plot(dates,S_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('S')
ax1.set_title('Susceptible')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])
# ax1[0].grid(axis='y')

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,VV, '--g')
ax1.plot(dates,V_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('V')
ax1.set_title('Vaccinated')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,EE, '--g')
ax1.plot(dates,E_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('E')
ax1.set_title('Exposed')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,I1I, '--g')

ax1.plot(dates,I1_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('I1')
ax1.set_title('Mild Infected')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,I2I, '--g')
ax1.plot(dates,I2_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('I2')
ax1.set_title('Infected in the Hospital')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,I3I, '--g')
ax1.plot(dates,I3_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('I3')
ax1.set_title('Infected in the ICU')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,RR, '--g')
ax1.plot(dates,R_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('R')
ax1.set_title('Recovered')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
fig1, ax1 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax1.plot(dates,DD, '--g')
ax1.plot(dates,D_pred_m.flatten().tolist(), '--b')

ax1.set_xlabel('Date')
ax1.set_ylabel('D')
ax1.set_title('Death')
ax1.set_xlim(lims)
ax1.legend(['Actual Data',r'Fitted Data'])

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, constrained_layout=True, figsize=(24, 16))

# Custom plots for each subplot
def plot_1(ax):
    ax.plot(dates,SS, '--g')
    ax.plot(dates,S_pred_m.flatten().tolist(), '--b')
    ax.set_xlabel('Date')
    ax.set_ylabel('S')
    ax.set_title('Susceptible')
    ax.set_xlim(lims)
    ax.legend(['Actual Data',r'Fitted Data'], loc='upper right')


def plot_2(ax):
    ax.plot(dates,VV, '--g')
    ax.plot(dates,V_pred_m.flatten().tolist(), '--b')
    ax.set_xlabel('Date')
    ax.set_ylabel('V')
    ax.set_title('Vaccinated')
    ax.set_xlim(lims)
    ax.legend(['Actual Data',r'Fitted Data'], loc='upper right')


def plot_3(ax):
    ax.plot(dates,EE, '--g')
    ax.plot(dates,E_pred_m.flatten().tolist(), '--b')
    ax.set_xlabel('Date')
    ax.set_ylabel('E')
    ax.set_title('Exposed')
    ax.set_xlim(lims)
    ax.legend(['Actual Data',r'Fitted Data'], loc='upper right')


def plot_4(ax):
    ax.plot(dates,I1I, '--g')
    ax.plot(dates,I1_pred_m.flatten().tolist(), '--b')
    ax.set_xlabel('Date')
    ax.set_ylabel('I1')
    ax.set_title('Mild Infected')
    ax.set_xlim(lims)
    ax.legend(['Actual Data',r'Fitted Data'], loc='upper right')


# Apply different plots to each subplot
plot_1(axs[0, 0])
plot_2(axs[0, 1])
plot_3(axs[1, 0])
plot_4(axs[1, 1])

# Set common labels 
for ax in axs.flat:
    ax.set_xlabel('Date')


# Display the plot
# plt.show()
plt.savefig('sto_test_data_fitting_'+str(POINTS)+'xpoints_'+str(GRID)+'0%grid_seed'+str(SEED)+'.png')

# %%
print('TOTAL_RMSE', total_rmse)
print('TOTAL_MAPE', total_mape)
# Out:
# TOTAL_RMSE 0.004184661686718738
# TOTAL_MAPE 10.517848552141137

# %%
print('alpha', alpha)
print('sigma',sigma) 
print('beta1',beta1) 
print('beta2',beta2)
print('beta3',beta3)
print('delta1',delta1)
print('delta2',delta2)
print('delta3',delta3)
print('gamma',gamma)
print('p1',p1)
print('p2',p2)
print('mu',mu)
print('sigma1',sigma1) 
print('sigma2',sigma2)
print('sigma3',sigma3)
print('sigma4',sigma4)
print('sigma5',sigma5)
print('sigma6',sigma6)
print('sigma7',sigma7)
print('sigma8',sigma8)

fig2, ax2 = plt.subplots(1, 1,constrained_layout=True,figsize=(12, 8))
ax2.plot(total_loss)
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Loss')
plt.savefig('sto_test_loss_'+str(POINTS)+'xpoints_'+str(GRID)+'0%grid_seed'+str(SEED)+'.png')
# Out:
# alpha 0.00171
# sigma 0.06353
# beta1 0.28121
# beta2 0.15838
# beta3 0.03881
# delta1 0.28505
# delta2 0.28269
# delta3 0.14206
# gamma 0.30959
# p1 0.02089
# p2 0.14311
# mu 0.00492
# sigma1 0.09278
# sigma2 0.03863
# sigma3 0.07516
# sigma4 0.06305
# sigma5 0.07877
# sigma6 0.06125
# sigma7 0.06111
# sigma8 0.06199
