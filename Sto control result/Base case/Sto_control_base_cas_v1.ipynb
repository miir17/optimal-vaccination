# %% [markdown]
# Hyperparameter
# - ITERS = 10000
# - layers = [1,128,128,128,128,8]
# - BATCH = 16
# - NUM_HIDDEN = 1
# - MOMENTUM = 0.8
# - learning_rate = 1e-6
# - lr_rate = [1e-3, 1e-4, 1e-6]
# - lr_boundaries = [5000, 8000]

# %%
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as normal

tf.keras.backend.set_floatx('float64')
tf.compat.v1.enable_eager_execution()

# %%
NUM_OF_INTERNAL = 60
TOTAL_T = 60
NUM_HIDDEN = 1
MOMENTUM = 0.8
BATCH = 16
K = 5
ITERS = 10000
SEED = 12345
TEXT = "base_case" #change this one

c1 = 100 
c2 = 20
c3 = 50
c4 = 200
c5 = 1000
c6 = 300*1/2

# %%
birth =  0.000053
death =  0.000033 

alpha = 0.00135
sigma = 0.06352
beta1 = 0.2812 
beta2 = 0.15838 
beta3 = 0.0388 
delta1 = 0.28505
delta2 = 0.28269
delta3 = 0.14206
gamma = 0.30954
p1 = 0.01845
p2 = 0.1431
mu = 0.0042
sigma1 = 0.09275
sigma2 = 0.03887
sigma3 = 0.07517
sigma4 = 0.06302
sigma5 = 0.07878
sigma6 = 0.06123
sigma7 = 0.0611
sigma8 = 0.06199

N = 6629870
S0 = 3674149/N
V0 = 2845438/N
E0 = 67789/N
I10 = 12113/N
I20 = 498/N
I30 = 96/N
R0 = 28911/N
D0 = 876/N

init = [S0, V0, E0, I10, I20, I30, R0, D0]

# %%
k0 = 0.006
k1 = -0.1341

def p1fn(alpha):
    return k0 + k1 * alpha

# %%
class Solver(object):

    def __init__(self, seed_var):
        self.valid_size = BATCH
        self.batch_size = BATCH
        
        self.num_iterations = ITERS
        self.print_frequency = 100
        self.lr_values = [1e-3, 1e-4, 1e-6]
        self.lr_boundaries = [5000, 8000]
        self.config = Config()

        self.model = WholeNet(seed_var)
        lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(self.lr_boundaries, self.lr_values)
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, epsilon=1e-7)

    def train(self):
        """Training the model"""
        start_time = time.time()
        training_history = []
        control_output = [] 
        
        dW = self.config.sample(self.valid_size)
        valid_data = dW
        for step in range(self.num_iterations+1):
            if step % self.print_frequency == 0:
                cost, row_out0 = self.model(valid_data, training=True)
                elapsed_time = time.time() - start_time
                training_history.append([step, cost, elapsed_time])
                print("step: %5u, Cost: %.4e, elapsed time: %3u" % (step, cost, elapsed_time))
            if step == self.num_iterations:
                cost1, row_out1 = self.model(valid_data, training=True)
                row_output = row_out1.numpy()
                control_output.append(row_output)
            self.train_step(self.config.sample(self.batch_size))
        self.training_history = training_history
        self.control_output = control_output

    @tf.function
    def train_step(self, train_data):
        """Updating the gradients"""
        with tf.GradientTape(persistent=True) as tape:
            loss = self.model(train_data, training = True)
        grad = tape.gradient(loss, self.model.trainable_variables)
        del tape
        self.optimizer.apply_gradients(zip(grad, self.model.trainable_variables))

# %%
class WholeNet(tf.keras.Model):
    """Building the neural network architecture"""
    def __init__(self,seed_var):
        super(WholeNet, self).__init__()
        self.config = Config()
        self.subnet = [FNNet(seed_var) for _ in range(self.config.num_time_interval)]

    def call(self, dw, training):
        x_init = tf.ones([1, self.config.dim_x], dtype=tf.dtypes.float64) * init
        time_stamp = np.arange(0, self.config.num_time_interval) * self.config.delta_t
        all_ones = tf.ones([tf.shape(dw)[0], 1], dtype=tf.dtypes.float64)

        # initial state
        x = tf.matmul(all_ones, x_init)

        # initial cost functional
        l = 0.0 
        u_set = []
        for t in range(0, self.config.num_time_interval):
            u = self.subnet[t](x, training)
            u_set.append(tf.stack([u], axis=0))   
            l = l + self.config.f_fn(time_stamp[t], x, u) * self.config.delta_t
            x = x + self.config.b_fn(time_stamp[t], x, u) * self.config.delta_t + self.config.sigma_fn(time_stamp[t], x, u) * dw[:,:,  t]

        # control variable
        control_u = tf.stack(u_set, axis=0)
        row_ave2 = tf.reduce_mean(control_u, axis=2)
        row_out1 = tf.squeeze(row_ave2, axis=[1,2])
        #print("u timepath2", row_ave2)
        
        # terminal condition
        l = l + self.config.h_fn(self.config.total_time, x)
        cost = tf.reduce_mean(l) 
        return cost, row_out1

# %%
class FNNet(tf.keras.Model):
    def __init__(self, seed_var):
        super(FNNet, self).__init__()
        self.config = Config()

        tf.random.set_seed(seed_var)
        np.random.seed(seed_var)
        
        num_hiddens = [self.config.dim_x + NUM_HIDDEN, self.config.dim_x + NUM_HIDDEN, self.config.dim_x + NUM_HIDDEN]
        self.bn_layers = [
            tf.keras.layers.BatchNormalization(
                momentum=MOMENTUM,
                epsilon=1e-6,
                beta_initializer=tf.random_normal_initializer(0.0, stddev=0.1,seed=seed_var),
                gamma_initializer=tf.random_uniform_initializer(0.1, 0.5,seed=seed_var)
            )
            for _ in range(len(num_hiddens) + 2)]
        self.dense_layers = [tf.keras.layers.Dense(num_hiddens[i],
                                                   use_bias=True,
                                                   activation='tanh')
                             for i in range(len(num_hiddens))]
        
        # final output should be gradient of size dim_u
        self.dense_layers.append(tf.keras.layers.Dense(self.config.dim_u, activation='sigmoid'))

    def call(self, x, training):
        x = self.bn_layers[0](x, training)
        for i in range(len(self.dense_layers) - 1):
            x = self.dense_layers[i](x)
            x = self.bn_layers[i+1](x, training)
            x = tf.nn.tanh(x)
        x = self.dense_layers[-1](x)
        x = self.bn_layers[-1](x, training)
        return tf.nn.tanh(x) * 0.012 + 0.016

# %%
class Config(object):
    """function config"""
    def __init__(self):
        super(Config, self).__init__()
        self.dim_x = 8
        self.dim_u = 1
        self.num_time_interval = NUM_OF_INTERNAL
        self.total_time = TOTAL_T
        self.delta_t = (self.total_time + 0.0) / self.num_time_interval
        self.sqrth = np.sqrt(self.delta_t)
        self.t_stamp = np.arange(0, self.num_time_interval) * self.delta_t

    # sample function
    def sample(self, num_sample):
        dw_sample = normal.rvs(size=[num_sample, self.dim_x, self.num_time_interval]) * self.sqrth
        return dw_sample

    # cost functional integral item
    def f_fn(self, t, x, u):
        tensors = []
        for i in range(BATCH):
            S = x[i][0]
            V = x[i][1]
            E = x[i][2]
            I1 = x[i][3]
            I2 = x[i][4]
            I3 = x[i][5]
            R = x[i][6]
            D = x[i][7]
            alpha = u[i][0]  
            cost = (c1 * alpha ** 2 + c2 * E + (c3*I1 + c4*I2 + c5*I3) + c6 * (tf.maximum(tf.cast(0, tf.float64), 1-(S+V+R)))) 
            combined_cost = tf.stack([cost], axis=0)
            tensors.append(combined_cost)
            combined_tensor = tf.stack(tensors, axis=0)
        return tf.reduce_sum(combined_tensor, 1, keepdims=True)

    # cost fuctional terminal function
    def h_fn(self, t, x):
        return 0

    def b_fn(self, t, x, u):
        tensors = []
        for i in range(BATCH):
            S = x[i][0]
            V = x[i][1]
            E = x[i][2]
            I1 = x[i][3]
            I2 = x[i][4]
            I3 = x[i][5]
            R = x[i][6]
            D = x[i][7]
            alpha = u[i][0]
            dS = birth + (- ( beta1 * I1 + beta2 * I2 + beta3 * I3) * S  - alpha * S) - death*S
            dV = (alpha * S - sigma * (beta1 * I1 + beta2 * I2 + beta3 * I3) * V) - death*V
            dE = ((beta1 * I1 + beta2 * I2 + beta3 * I3) * S  + sigma * (beta1 * I1 + beta2 * I2 + beta3 * I3) * V - gamma * E) - death*E
            dI1 = (gamma * E - (delta1 + p1fn(alpha)) * I1) - death*I1
            dI2 = (p1fn(alpha) * I1 - (delta2 + p2) * I2) - death*I2
            dI3 = (p2 * I2 - (delta3 + mu) * I3) - death*I3
            dR = (delta1 * I1+ delta2 * I2 + delta3 * I3) - death*R
            dD = (mu * I3) 
            combined_ten = tf.stack([dS, dV,dE,dI1,dI2,dI3,dR,dD], axis=0)
            tensors.append(combined_ten)
            combined_tensor = tf.stack(tensors, axis=0)
        return combined_tensor

    def sigma_fn(self, t, x, u):
        #return x
        tensors = []
        for i in range(BATCH):
            S = x[i][0]
            V = x[i][1]
            E = x[i][2]
            I1 = x[i][3]
            I2 = x[i][4]
            I3 = x[i][5]
            R = x[i][6]
            D = x[i][7]
            sig_S = sigma1*S
            sig_V = sigma2*V
            sig_E = sigma3*E
            sig_I1 = sigma4*I1
            sig_I2 = sigma5*I2
            sig_I3 = sigma6*I3
            sig_R = sigma7*R
            sig_D = sigma8*D
            combined_sig = tf.stack([sig_S, sig_V,sig_E,sig_I1,sig_I2,sig_I3,sig_R,sig_D], axis=0)
            tensors.append(combined_sig)
            combined_tensor = tf.stack(tensors, axis=0)
        return combined_tensor

# %%
output_table = np.zeros((int(round(ITERS) / 100) + 1, 2 + int(round(K))))
control_outs_table = np.zeros((int(round(K)), TOTAL_T))


def main():
    solver = Solver(seed_var=SEED)
    print('Training time %3u:' % (1))
    solver.train()
    data = np.array(solver.training_history)
    control_output_data = np.array(solver.control_output)
    k = K
    
    output = np.zeros((len(data[:, 0]), 2 + k))
    output[:, 0] = data[:, 0]
    output[:, 1] = data[:, 2]
    output[:, 2] = data[:, 1]
    output_table[:, 0] = data[:, 0]
    output_table[:, 1] = data[:, 2]
    output_table[:, 2] = data[:, 1]

    
    control_outs = np.zeros((k, len(control_output_data[0])))
    control_outs[0] = control_output_data[0]

    
    for i in range(k - 1):
        print('Training time %3u:' % (i + 2))
        solver = Solver(seed_var=12345+1+i)  
        solver.train()
        data = np.array(solver.training_history)
        control_output_data = np.array(solver.control_output)
        output[:, 3 + i] = data[:, 1]
        output_table[:, 3 + i] = data[:, 1]
        control_outs[1+i] = control_output_data[0]
        control_outs_table[1+i] = control_output_data[0]

    a = ['%d', '%.5e']
    for _ in range(k):
        a.append('%.5e')
    
    con_format = ['%.5e']
    for _ in range(len(control_output_data[0])-1):
        con_format.append('%.5e')
        
    np.savetxt('./Sto_control_Opt_Vacc_'+str(TEXT)+'.csv', control_outs, fmt=con_format, delimiter=',')
    np.savetxt('./Sto_control_Loss_'+str(TEXT)+'.csv', output, fmt=a, delimiter=',')
    print('Solving is done!')

if __name__ == '__main__':
    main()
# Out:
# 2025-12-06 13:36:43.309135: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-12-06 13:36:43.309476: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training time   1:
# step:     0, Cost: 7.8076e+02, elapsed time:   6
# 2025-12-06 13:41:51.516377: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# step:   100, Cost: 7.7577e+02, elapsed time: 478
# step:   200, Cost: 7.7417e+02, elapsed time: 496
# step:   300, Cost: 7.7227e+02, elapsed time: 514
# step:   400, Cost: 7.6911e+02, elapsed time: 532
# step:   500, Cost: 7.6684e+02, elapsed time: 550
# step:   600, Cost: 7.6565e+02, elapsed time: 568
# step:   700, Cost: 7.6559e+02, elapsed time: 586
# step:   800, Cost: 7.6510e+02, elapsed time: 604
# step:   900, Cost: 7.6537e+02, elapsed time: 622
# step:  1000, Cost: 7.6481e+02, elapsed time: 641
# step:  1100, Cost: 7.6507e+02, elapsed time: 659
# step:  1200, Cost: 7.6305e+02, elapsed time: 677
# step:  1300, Cost: 7.6280e+02, elapsed time: 696
# step:  1400, Cost: 7.6394e+02, elapsed time: 714
# step:  1500, Cost: 7.6316e+02, elapsed time: 733
# step:  1600, Cost: 7.6472e+02, elapsed time: 752
# step:  1700, Cost: 7.6357e+02, elapsed time: 770
# step:  1800, Cost: 7.6457e+02, elapsed time: 788
# step:  1900, Cost: 7.6429e+02, elapsed time: 806
# step:  2000, Cost: 7.6534e+02, elapsed time: 824
# step:  2100, Cost: 7.6453e+02, elapsed time: 843
# step:  2200, Cost: 7.6514e+02, elapsed time: 861
# step:  2300, Cost: 7.6540e+02, elapsed time: 879
# step:  2400, Cost: 7.6534e+02, elapsed time: 897
# step:  2500, Cost: 7.6581e+02, elapsed time: 916
# step:  2600, Cost: 7.6433e+02, elapsed time: 935
# step:  2700, Cost: 7.6449e+02, elapsed time: 954
# step:  2800, Cost: 7.6411e+02, elapsed time: 973
# step:  2900, Cost: 7.6435e+02, elapsed time: 991
# step:  3000, Cost: 7.6482e+02, elapsed time: 1009
# step:  3100, Cost: 7.6524e+02, elapsed time: 1027
# step:  3200, Cost: 7.6698e+02, elapsed time: 1046
# step:  3300, Cost: 7.6628e+02, elapsed time: 1064
# step:  3400, Cost: 7.6667e+02, elapsed time: 1082
# step:  3500, Cost: 7.6511e+02, elapsed time: 1100
# step:  3600, Cost: 7.6570e+02, elapsed time: 1118
# step:  3700, Cost: 7.6606e+02, elapsed time: 1137
# step:  3800, Cost: 7.6652e+02, elapsed time: 1156
# step:  3900, Cost: 7.6603e+02, elapsed time: 1175
# step:  4000, Cost: 7.6672e+02, elapsed time: 1193
# step:  4100, Cost: 7.6667e+02, elapsed time: 1211
# step:  4200, Cost: 7.6705e+02, elapsed time: 1230
# step:  4300, Cost: 7.6567e+02, elapsed time: 1249
# step:  4400, Cost: 7.6763e+02, elapsed time: 1267
# step:  4500, Cost: 7.6756e+02, elapsed time: 1286
# step:  4600, Cost: 7.6602e+02, elapsed time: 1304
# step:  4700, Cost: 7.6548e+02, elapsed time: 1323
# step:  4800, Cost: 7.6692e+02, elapsed time: 1341
# step:  4900, Cost: 7.6705e+02, elapsed time: 1359
# step:  5000, Cost: 7.6709e+02, elapsed time: 1378
# step:  5100, Cost: 7.6701e+02, elapsed time: 1396
# step:  5200, Cost: 7.6694e+02, elapsed time: 1415
# step:  5300, Cost: 7.6686e+02, elapsed time: 1433
# step:  5400, Cost: 7.6681e+02, elapsed time: 1452
# step:  5500, Cost: 7.6676e+02, elapsed time: 1470
# step:  5600, Cost: 7.6679e+02, elapsed time: 1489
# step:  5700, Cost: 7.6677e+02, elapsed time: 1508
# step:  5800, Cost: 7.6682e+02, elapsed time: 1527
# step:  5900, Cost: 7.6681e+02, elapsed time: 1546
# step:  6000, Cost: 7.6677e+02, elapsed time: 1564
# step:  6100, Cost: 7.6677e+02, elapsed time: 1583
# step:  6200, Cost: 7.6667e+02, elapsed time: 1601
# step:  6300, Cost: 7.6655e+02, elapsed time: 1620
# step:  6400, Cost: 7.6649e+02, elapsed time: 1638
# step:  6500, Cost: 7.6646e+02, elapsed time: 1657
# step:  6600, Cost: 7.6650e+02, elapsed time: 1676
# step:  6700, Cost: 7.6644e+02, elapsed time: 1695
# step:  6800, Cost: 7.6637e+02, elapsed time: 1715
# step:  6900, Cost: 7.6634e+02, elapsed time: 1736
# step:  7000, Cost: 7.6631e+02, elapsed time: 1756
# step:  7100, Cost: 7.6632e+02, elapsed time: 1778
# step:  7200, Cost: 7.6626e+02, elapsed time: 1798
# step:  7300, Cost: 7.6633e+02, elapsed time: 1819
# step:  7400, Cost: 7.6626e+02, elapsed time: 1840
# step:  7500, Cost: 7.6626e+02, elapsed time: 1860
# step:  7600, Cost: 7.6617e+02, elapsed time: 1881
# step:  7700, Cost: 7.6619e+02, elapsed time: 1902
# step:  7800, Cost: 7.6616e+02, elapsed time: 1923
# step:  7900, Cost: 7.6625e+02, elapsed time: 1943
# step:  8000, Cost: 7.6630e+02, elapsed time: 1964
# step:  8100, Cost: 7.6630e+02, elapsed time: 1985
# step:  8200, Cost: 7.6630e+02, elapsed time: 2006
# step:  8300, Cost: 7.6629e+02, elapsed time: 2027
# step:  8400, Cost: 7.6629e+02, elapsed time: 2048
# step:  8500, Cost: 7.6629e+02, elapsed time: 2068
# step:  8600, Cost: 7.6629e+02, elapsed time: 2089
# step:  8700, Cost: 7.6629e+02, elapsed time: 2109
# step:  8800, Cost: 7.6629e+02, elapsed time: 2131
# step:  8900, Cost: 7.6629e+02, elapsed time: 2155
# step:  9000, Cost: 7.6629e+02, elapsed time: 2179
# step:  9100, Cost: 7.6629e+02, elapsed time: 2203
# step:  9200, Cost: 7.6629e+02, elapsed time: 2226
# step:  9300, Cost: 7.6629e+02, elapsed time: 2249
# step:  9400, Cost: 7.6629e+02, elapsed time: 2271
# step:  9500, Cost: 7.6629e+02, elapsed time: 2295
# step:  9600, Cost: 7.6629e+02, elapsed time: 2318
# step:  9700, Cost: 7.6629e+02, elapsed time: 2341
# step:  9800, Cost: 7.6629e+02, elapsed time: 2364
# step:  9900, Cost: 7.6629e+02, elapsed time: 2387
# step: 10000, Cost: 7.6629e+02, elapsed time: 2409
# Training time   2:
# step:     0, Cost: 5.9624e+02, elapsed time:   3
# step:   100, Cost: 5.9129e+02, elapsed time: 540
# step:   200, Cost: 5.8738e+02, elapsed time: 558
# step:   300, Cost: 5.8261e+02, elapsed time: 576
# step:   400, Cost: 5.7794e+02, elapsed time: 593
# step:   500, Cost: 5.7409e+02, elapsed time: 610
# step:   600, Cost: 5.7179e+02, elapsed time: 627
# step:   700, Cost: 5.6939e+02, elapsed time: 645
# step:   800, Cost: 5.6715e+02, elapsed time: 663
# step:   900, Cost: 5.6603e+02, elapsed time: 681
# step:  1000, Cost: 5.6456e+02, elapsed time: 698
# step:  1100, Cost: 5.6256e+02, elapsed time: 715
# step:  1200, Cost: 5.6104e+02, elapsed time: 733
# step:  1300, Cost: 5.6021e+02, elapsed time: 750
# step:  1400, Cost: 5.5927e+02, elapsed time: 767
# step:  1500, Cost: 5.5823e+02, elapsed time: 784
# step:  1600, Cost: 5.5734e+02, elapsed time: 801
# step:  1700, Cost: 5.5649e+02, elapsed time: 818
# step:  1800, Cost: 5.5584e+02, elapsed time: 836
# step:  1900, Cost: 5.5541e+02, elapsed time: 853
# step:  2000, Cost: 5.5470e+02, elapsed time: 870
# step:  2100, Cost: 5.5432e+02, elapsed time: 887
# step:  2200, Cost: 5.5396e+02, elapsed time: 906
# step:  2300, Cost: 5.5370e+02, elapsed time: 924
# step:  2400, Cost: 5.5333e+02, elapsed time: 943
# step:  2500, Cost: 5.5279e+02, elapsed time: 962
# step:  2600, Cost: 5.5287e+02, elapsed time: 980
# step:  2700, Cost: 5.5283e+02, elapsed time: 999
# step:  2800, Cost: 5.5283e+02, elapsed time: 1018
# step:  2900, Cost: 5.5275e+02, elapsed time: 1037
# step:  3000, Cost: 5.5235e+02, elapsed time: 1054
# step:  3100, Cost: 5.5190e+02, elapsed time: 1071
# step:  3200, Cost: 5.5162e+02, elapsed time: 1088
# step:  3300, Cost: 5.5178e+02, elapsed time: 1106
# step:  3400, Cost: 5.5190e+02, elapsed time: 1123
# step:  3500, Cost: 5.5163e+02, elapsed time: 1141
# step:  3600, Cost: 5.5132e+02, elapsed time: 1158
# step:  3700, Cost: 5.5119e+02, elapsed time: 1176
# step:  3800, Cost: 5.5114e+02, elapsed time: 1193
# step:  3900, Cost: 5.5102e+02, elapsed time: 1211
# step:  4000, Cost: 5.5103e+02, elapsed time: 1229
# step:  4100, Cost: 5.5063e+02, elapsed time: 1246
# step:  4200, Cost: 5.5072e+02, elapsed time: 1263
# step:  4300, Cost: 5.5045e+02, elapsed time: 1280
# step:  4400, Cost: 5.5014e+02, elapsed time: 1297
# step:  4500, Cost: 5.5039e+02, elapsed time: 1314
# step:  4600, Cost: 5.5019e+02, elapsed time: 1331
# step:  4700, Cost: 5.5041e+02, elapsed time: 1348
# step:  4800, Cost: 5.5027e+02, elapsed time: 1366
# step:  4900, Cost: 5.5026e+02, elapsed time: 1383
# step:  5000, Cost: 5.5007e+02, elapsed time: 1400
# step:  5100, Cost: 5.5006e+02, elapsed time: 1417
# step:  5200, Cost: 5.5005e+02, elapsed time: 1435
# step:  5300, Cost: 5.5004e+02, elapsed time: 1453
# step:  5400, Cost: 5.5003e+02, elapsed time: 1470
# step:  5500, Cost: 5.5002e+02, elapsed time: 1488
# step:  5600, Cost: 5.5002e+02, elapsed time: 1506
# step:  5700, Cost: 5.5001e+02, elapsed time: 1524
# step:  5800, Cost: 5.5000e+02, elapsed time: 1542
# step:  5900, Cost: 5.4998e+02, elapsed time: 1559
# step:  6000, Cost: 5.4997e+02, elapsed time: 1577
# step:  6100, Cost: 5.4998e+02, elapsed time: 1595
# step:  6200, Cost: 5.4997e+02, elapsed time: 1613
# step:  6300, Cost: 5.4991e+02, elapsed time: 1631
# step:  6400, Cost: 5.4989e+02, elapsed time: 1648
# step:  6500, Cost: 5.4990e+02, elapsed time: 1666
# step:  6600, Cost: 5.4986e+02, elapsed time: 1684
# step:  6700, Cost: 5.4988e+02, elapsed time: 1702
# step:  6800, Cost: 5.4985e+02, elapsed time: 1719
# step:  6900, Cost: 5.4982e+02, elapsed time: 1736
# step:  7000, Cost: 5.4981e+02, elapsed time: 1753
# step:  7100, Cost: 5.4983e+02, elapsed time: 1798
# step:  7200, Cost: 5.4981e+02, elapsed time: 1816
# step:  7300, Cost: 5.4980e+02, elapsed time: 1833
# step:  7400, Cost: 5.4979e+02, elapsed time: 1874
# step:  7500, Cost: 5.4979e+02, elapsed time: 1890
# step:  7600, Cost: 5.4981e+02, elapsed time: 1906
# step:  7700, Cost: 5.4980e+02, elapsed time: 2602
# step:  7800, Cost: 5.4981e+02, elapsed time: 2618
# step:  7900, Cost: 5.4978e+02, elapsed time: 2635
# step:  8000, Cost: 5.4978e+02, elapsed time: 2710
# step:  8100, Cost: 5.4978e+02, elapsed time: 2726
# step:  8200, Cost: 5.4978e+02, elapsed time: 2742
# step:  8300, Cost: 5.4978e+02, elapsed time: 2848
# step:  8400, Cost: 5.4978e+02, elapsed time: 2864
# step:  8500, Cost: 5.4978e+02, elapsed time: 2880
# step:  8600, Cost: 5.4978e+02, elapsed time: 2971
# step:  8700, Cost: 5.4978e+02, elapsed time: 2987
# step:  8800, Cost: 5.4978e+02, elapsed time: 3003
# step:  8900, Cost: 5.4978e+02, elapsed time: 3020
# step:  9000, Cost: 5.4978e+02, elapsed time: 3036
# step:  9100, Cost: 5.4978e+02, elapsed time: 3822
# step:  9200, Cost: 5.4978e+02, elapsed time: 3839
# step:  9300, Cost: 5.4978e+02, elapsed time: 3857
# step:  9400, Cost: 5.4978e+02, elapsed time: 3875
# step:  9500, Cost: 5.4978e+02, elapsed time: 3893
# step:  9600, Cost: 5.4977e+02, elapsed time: 3911
# step:  9700, Cost: 5.4977e+02, elapsed time: 3929
# step:  9800, Cost: 5.4977e+02, elapsed time: 3947
# step:  9900, Cost: 5.4977e+02, elapsed time: 3965
# step: 10000, Cost: 5.4977e+02, elapsed time: 3983
# Training time   3:
# step:     0, Cost: 5.8557e+02, elapsed time:   3
# step:   100, Cost: 5.7738e+02, elapsed time: 491
# step:   200, Cost: 5.7252e+02, elapsed time: 508
# step:   300, Cost: 5.6479e+02, elapsed time: 526
# step:   400, Cost: 5.6256e+02, elapsed time: 545
# step:   500, Cost: 5.6469e+02, elapsed time: 562
# step:   600, Cost: 5.6103e+02, elapsed time: 580
# step:   700, Cost: 5.6211e+02, elapsed time: 598
# step:   800, Cost: 5.6380e+02, elapsed time: 616
# step:   900, Cost: 5.6102e+02, elapsed time: 634
# step:  1000, Cost: 5.5677e+02, elapsed time: 652
# step:  1100, Cost: 5.5518e+02, elapsed time: 670
# step:  1200, Cost: 5.5213e+02, elapsed time: 688
# step:  1300, Cost: 5.5451e+02, elapsed time: 706
# step:  1400, Cost: 5.4991e+02, elapsed time: 724
# step:  1500, Cost: 5.4960e+02, elapsed time: 741
# step:  1600, Cost: 5.4775e+02, elapsed time: 759
# step:  1700, Cost: 5.4985e+02, elapsed time: 777
# step:  1800, Cost: 5.4629e+02, elapsed time: 795
# step:  1900, Cost: 5.4472e+02, elapsed time: 813
# step:  2000, Cost: 5.4578e+02, elapsed time: 830
# step:  2100, Cost: 5.4464e+02, elapsed time: 848
# step:  2200, Cost: 5.4403e+02, elapsed time: 866
# step:  2300, Cost: 5.4517e+02, elapsed time: 884
# step:  2400, Cost: 5.4513e+02, elapsed time: 902
# step:  2500, Cost: 5.4584e+02, elapsed time: 920
# step:  2600, Cost: 5.4344e+02, elapsed time: 939
# step:  2700, Cost: 5.4314e+02, elapsed time: 957
# step:  2800, Cost: 5.4388e+02, elapsed time: 975
# step:  2900, Cost: 5.4313e+02, elapsed time: 993
# step:  3000, Cost: 5.4277e+02, elapsed time: 1011
# step:  3100, Cost: 5.4070e+02, elapsed time: 1029
# step:  3200, Cost: 5.3970e+02, elapsed time: 1047
# step:  3300, Cost: 5.4057e+02, elapsed time: 1065
# step:  3400, Cost: 5.4035e+02, elapsed time: 1083
# step:  3500, Cost: 5.3919e+02, elapsed time: 1101
# step:  3600, Cost: 5.4080e+02, elapsed time: 1120
# step:  3700, Cost: 5.4112e+02, elapsed time: 1137
# step:  3800, Cost: 5.4104e+02, elapsed time: 1155
# step:  3900, Cost: 5.3977e+02, elapsed time: 1172
# step:  4000, Cost: 5.3946e+02, elapsed time: 1189
# step:  4100, Cost: 5.3949e+02, elapsed time: 1206
# step:  4200, Cost: 5.3907e+02, elapsed time: 1223
# step:  4300, Cost: 5.3956e+02, elapsed time: 1239
# step:  4400, Cost: 5.4055e+02, elapsed time: 1256
# step:  4500, Cost: 5.4006e+02, elapsed time: 1273
# step:  4600, Cost: 5.4020e+02, elapsed time: 1290
# step:  4700, Cost: 5.4000e+02, elapsed time: 1307
# step:  4800, Cost: 5.4015e+02, elapsed time: 1324
# step:  4900, Cost: 5.4035e+02, elapsed time: 1340
# step:  5000, Cost: 5.4016e+02, elapsed time: 1357
# step:  5100, Cost: 5.4013e+02, elapsed time: 1374
# step:  5200, Cost: 5.4005e+02, elapsed time: 1391
# step:  5300, Cost: 5.4009e+02, elapsed time: 1408
# step:  5400, Cost: 5.4011e+02, elapsed time: 1425
# step:  5500, Cost: 5.4009e+02, elapsed time: 1441
# step:  5600, Cost: 5.4005e+02, elapsed time: 1458
# step:  5700, Cost: 5.4002e+02, elapsed time: 1475
# step:  5800, Cost: 5.4012e+02, elapsed time: 1492
# step:  5900, Cost: 5.4017e+02, elapsed time: 1509
# step:  6000, Cost: 5.4019e+02, elapsed time: 1526
# step:  6100, Cost: 5.4016e+02, elapsed time: 1543
# step:  6200, Cost: 5.4014e+02, elapsed time: 1560
# step:  6300, Cost: 5.4016e+02, elapsed time: 1577
# step:  6400, Cost: 5.4015e+02, elapsed time: 1595
# step:  6500, Cost: 5.4011e+02, elapsed time: 1612
# step:  6600, Cost: 5.4009e+02, elapsed time: 1630
# step:  6700, Cost: 5.4004e+02, elapsed time: 1647
# step:  6800, Cost: 5.4006e+02, elapsed time: 1664
# step:  6900, Cost: 5.4010e+02, elapsed time: 1681
# step:  7000, Cost: 5.3999e+02, elapsed time: 1698
# step:  7100, Cost: 5.4001e+02, elapsed time: 1715
# step:  7200, Cost: 5.4001e+02, elapsed time: 1731
# step:  7300, Cost: 5.3997e+02, elapsed time: 1748
# step:  7400, Cost: 5.4002e+02, elapsed time: 1765
# step:  7500, Cost: 5.3993e+02, elapsed time: 1782
# step:  7600, Cost: 5.3981e+02, elapsed time: 1799
# step:  7700, Cost: 5.3978e+02, elapsed time: 1815
# step:  7800, Cost: 5.3967e+02, elapsed time: 1832
# step:  7900, Cost: 5.3959e+02, elapsed time: 1849
# step:  8000, Cost: 5.3967e+02, elapsed time: 1866
# step:  8100, Cost: 5.3967e+02, elapsed time: 1883
# step:  8200, Cost: 5.3967e+02, elapsed time: 1900
# step:  8300, Cost: 5.3967e+02, elapsed time: 1917
# step:  8400, Cost: 5.3967e+02, elapsed time: 1933
# step:  8500, Cost: 5.3967e+02, elapsed time: 1950
# step:  8600, Cost: 5.3967e+02, elapsed time: 1967
# step:  8700, Cost: 5.3967e+02, elapsed time: 1984
# step:  8800, Cost: 5.3967e+02, elapsed time: 2001
# step:  8900, Cost: 5.3967e+02, elapsed time: 2017
# step:  9000, Cost: 5.3967e+02, elapsed time: 2035
# step:  9100, Cost: 5.3967e+02, elapsed time: 2052
# step:  9200, Cost: 5.3967e+02, elapsed time: 2069
# step:  9300, Cost: 5.3967e+02, elapsed time: 2086
# step:  9400, Cost: 5.3967e+02, elapsed time: 2104
# step:  9500, Cost: 5.3967e+02, elapsed time: 2121
# step:  9600, Cost: 5.3966e+02, elapsed time: 2139
# step:  9700, Cost: 5.3967e+02, elapsed time: 2156
# step:  9800, Cost: 5.3967e+02, elapsed time: 2173
# step:  9900, Cost: 5.3967e+02, elapsed time: 2190
# step: 10000, Cost: 5.3967e+02, elapsed time: 2207
# Training time   4:
# step:     0, Cost: 6.3931e+02, elapsed time:   2
# step:   100, Cost: 6.4280e+02, elapsed time: 592
# step:   200, Cost: 6.4233e+02, elapsed time: 613
# step:   300, Cost: 6.3589e+02, elapsed time: 635
# step:   400, Cost: 6.3134e+02, elapsed time: 658
# step:   500, Cost: 6.2896e+02, elapsed time: 681
# step:   600, Cost: 6.3091e+02, elapsed time: 704
# step:   700, Cost: 6.2849e+02, elapsed time: 726
# step:   800, Cost: 6.2708e+02, elapsed time: 749
# step:   900, Cost: 6.2701e+02, elapsed time: 771
# step:  1000, Cost: 6.2588e+02, elapsed time: 794
# step:  1100, Cost: 6.2529e+02, elapsed time: 818
# step:  1200, Cost: 6.2575e+02, elapsed time: 841
# step:  1300, Cost: 6.2543e+02, elapsed time: 863
# step:  1400, Cost: 6.2359e+02, elapsed time: 886
# step:  1500, Cost: 6.2399e+02, elapsed time: 909
# step:  1600, Cost: 6.2422e+02, elapsed time: 932
# step:  1700, Cost: 6.2323e+02, elapsed time: 955
# step:  1800, Cost: 6.2286e+02, elapsed time: 978
# step:  1900, Cost: 6.2299e+02, elapsed time: 1000
# step:  2000, Cost: 6.2364e+02, elapsed time: 1023
# step:  2100, Cost: 6.2343e+02, elapsed time: 1046
# step:  2200, Cost: 6.2297e+02, elapsed time: 1069
# step:  2300, Cost: 6.2229e+02, elapsed time: 1092
# step:  2400, Cost: 6.2192e+02, elapsed time: 1115
# step:  2500, Cost: 6.2276e+02, elapsed time: 1138
# step:  2600, Cost: 6.2218e+02, elapsed time: 1161
# step:  2700, Cost: 6.2279e+02, elapsed time: 1185
# step:  2800, Cost: 6.2227e+02, elapsed time: 1208
# step:  2900, Cost: 6.2298e+02, elapsed time: 1233
# step:  3000, Cost: 6.2263e+02, elapsed time: 1257
# step:  3100, Cost: 6.2267e+02, elapsed time: 1281
# step:  3200, Cost: 6.2331e+02, elapsed time: 1305
# step:  3300, Cost: 6.2387e+02, elapsed time: 1329
# step:  3400, Cost: 6.2392e+02, elapsed time: 1354
# step:  3500, Cost: 6.2329e+02, elapsed time: 1378
# step:  3600, Cost: 6.2272e+02, elapsed time: 1401
# step:  3700, Cost: 6.2349e+02, elapsed time: 1425
# step:  3800, Cost: 6.2280e+02, elapsed time: 1448
# step:  3900, Cost: 6.2287e+02, elapsed time: 1472
# step:  4000, Cost: 6.2212e+02, elapsed time: 1496
# step:  4100, Cost: 6.2287e+02, elapsed time: 1519
# step:  4200, Cost: 6.2285e+02, elapsed time: 1544
# step:  4300, Cost: 6.2371e+02, elapsed time: 1569
# step:  4400, Cost: 6.2329e+02, elapsed time: 1591
# step:  4500, Cost: 6.2328e+02, elapsed time: 1609
# step:  4600, Cost: 6.2277e+02, elapsed time: 1627
# step:  4700, Cost: 6.2318e+02, elapsed time: 1645
# step:  4800, Cost: 6.2285e+02, elapsed time: 1664
# step:  4900, Cost: 6.2332e+02, elapsed time: 1682
# step:  5000, Cost: 6.2321e+02, elapsed time: 1701
# step:  5100, Cost: 6.2326e+02, elapsed time: 1719
# step:  5200, Cost: 6.2325e+02, elapsed time: 1737
# step:  5300, Cost: 6.2323e+02, elapsed time: 1755
# step:  5400, Cost: 6.2321e+02, elapsed time: 1774
# step:  5500, Cost: 6.2317e+02, elapsed time: 1792
# step:  5600, Cost: 6.2315e+02, elapsed time: 1810
# step:  5700, Cost: 6.2310e+02, elapsed time: 1828
# step:  5800, Cost: 6.2310e+02, elapsed time: 1846
# step:  5900, Cost: 6.2306e+02, elapsed time: 1864
# step:  6000, Cost: 6.2306e+02, elapsed time: 1882
# step:  6100, Cost: 6.2307e+02, elapsed time: 1901
# step:  6200, Cost: 6.2303e+02, elapsed time: 1919
# step:  6300, Cost: 6.2302e+02, elapsed time: 1937
# step:  6400, Cost: 6.2305e+02, elapsed time: 1955
# step:  6500, Cost: 6.2311e+02, elapsed time: 1973
# step:  6600, Cost: 6.2310e+02, elapsed time: 1992
# step:  6700, Cost: 6.2308e+02, elapsed time: 2010
# step:  6800, Cost: 6.2317e+02, elapsed time: 2028
# step:  6900, Cost: 6.2322e+02, elapsed time: 2046
# step:  7000, Cost: 6.2322e+02, elapsed time: 2064
# step:  7100, Cost: 6.2325e+02, elapsed time: 2082
# step:  7200, Cost: 6.2322e+02, elapsed time: 2101
# step:  7300, Cost: 6.2309e+02, elapsed time: 2119
# step:  7400, Cost: 6.2303e+02, elapsed time: 2137
# step:  7500, Cost: 6.2307e+02, elapsed time: 2155
# step:  7600, Cost: 6.2305e+02, elapsed time: 2173
# step:  7700, Cost: 6.2314e+02, elapsed time: 2192
# step:  7800, Cost: 6.2310e+02, elapsed time: 2210
# step:  7900, Cost: 6.2310e+02, elapsed time: 2228
# step:  8000, Cost: 6.2312e+02, elapsed time: 2247
# step:  8100, Cost: 6.2312e+02, elapsed time: 2265
# step:  8200, Cost: 6.2312e+02, elapsed time: 2283
# step:  8300, Cost: 6.2312e+02, elapsed time: 2301
# step:  8400, Cost: 6.2312e+02, elapsed time: 2319
# step:  8500, Cost: 6.2312e+02, elapsed time: 2336
# step:  8600, Cost: 6.2312e+02, elapsed time: 2354
# step:  8700, Cost: 6.2312e+02, elapsed time: 2372
# step:  8800, Cost: 6.2312e+02, elapsed time: 2389
# step:  8900, Cost: 6.2312e+02, elapsed time: 2407
# step:  9000, Cost: 6.2312e+02, elapsed time: 2424
# step:  9100, Cost: 6.2312e+02, elapsed time: 2442
# step:  9200, Cost: 6.2312e+02, elapsed time: 2460
# step:  9300, Cost: 6.2312e+02, elapsed time: 2477
# step:  9400, Cost: 6.2312e+02, elapsed time: 2495
# step:  9500, Cost: 6.2312e+02, elapsed time: 2513
# step:  9600, Cost: 6.2312e+02, elapsed time: 2530
# step:  9700, Cost: 6.2312e+02, elapsed time: 2548
# step:  9800, Cost: 6.2312e+02, elapsed time: 2566
# step:  9900, Cost: 6.2312e+02, elapsed time: 2583
# step: 10000, Cost: 6.2312e+02, elapsed time: 2601
# Training time   5:
# step:     0, Cost: 7.9804e+02, elapsed time:   3
# step:   100, Cost: 7.9193e+02, elapsed time: 461
# step:   200, Cost: 7.8922e+02, elapsed time: 479
# step:   300, Cost: 7.8639e+02, elapsed time: 496
# step:   400, Cost: 7.8245e+02, elapsed time: 514
# step:   500, Cost: 7.7920e+02, elapsed time: 531
# step:   600, Cost: 7.7514e+02, elapsed time: 549
# step:   700, Cost: 7.7247e+02, elapsed time: 567
# step:   800, Cost: 7.7028e+02, elapsed time: 584
# step:   900, Cost: 7.6964e+02, elapsed time: 602
# step:  1000, Cost: 7.6673e+02, elapsed time: 620
# step:  1100, Cost: 7.6690e+02, elapsed time: 637
# step:  1200, Cost: 7.6653e+02, elapsed time: 655
# step:  1300, Cost: 7.6539e+02, elapsed time: 672
# step:  1400, Cost: 7.6424e+02, elapsed time: 690
# step:  1500, Cost: 7.6358e+02, elapsed time: 708
# step:  1600, Cost: 7.6349e+02, elapsed time: 725
# step:  1700, Cost: 7.6296e+02, elapsed time: 743
# step:  1800, Cost: 7.6162e+02, elapsed time: 761
# step:  1900, Cost: 7.6155e+02, elapsed time: 778
# step:  2000, Cost: 7.6096e+02, elapsed time: 796
# step:  2100, Cost: 7.6035e+02, elapsed time: 814
# step:  2200, Cost: 7.6025e+02, elapsed time: 831
# step:  2300, Cost: 7.6016e+02, elapsed time: 849
# step:  2400, Cost: 7.5974e+02, elapsed time: 866
# step:  2500, Cost: 7.5980e+02, elapsed time: 883
# step:  2600, Cost: 7.5890e+02, elapsed time: 910
# step:  2700, Cost: 7.5830e+02, elapsed time: 927
# step:  2800, Cost: 7.5821e+02, elapsed time: 945
# step:  2900, Cost: 7.5809e+02, elapsed time: 963
# step:  3000, Cost: 7.5843e+02, elapsed time: 980
# step:  3100, Cost: 7.5808e+02, elapsed time: 1207
# step:  3200, Cost: 7.5773e+02, elapsed time: 1224
# step:  3300, Cost: 7.5814e+02, elapsed time: 1241
# step:  3400, Cost: 7.5805e+02, elapsed time: 1332
# step:  3500, Cost: 7.5763e+02, elapsed time: 1349
# step:  3600, Cost: 7.5725e+02, elapsed time: 1366
# step:  3700, Cost: 7.5656e+02, elapsed time: 1428
# step:  3800, Cost: 7.5649e+02, elapsed time: 1444
# step:  3900, Cost: 7.5617e+02, elapsed time: 1465
# step:  4000, Cost: 7.5620e+02, elapsed time: 1484
# step:  4100, Cost: 7.5616e+02, elapsed time: 1501
# step:  4200, Cost: 7.5629e+02, elapsed time: 1519
# step:  4300, Cost: 7.5630e+02, elapsed time: 1537
# step:  4400, Cost: 7.5632e+02, elapsed time: 1555
# step:  4500, Cost: 7.5630e+02, elapsed time: 1572
# step:  4600, Cost: 7.5582e+02, elapsed time: 1590
# step:  4700, Cost: 7.5576e+02, elapsed time: 1608
# step:  4800, Cost: 7.5560e+02, elapsed time: 1626
# step:  4900, Cost: 7.5557e+02, elapsed time: 1643
# step:  5000, Cost: 7.5552e+02, elapsed time: 1660
# step:  5100, Cost: 7.5548e+02, elapsed time: 1678
# step:  5200, Cost: 7.5549e+02, elapsed time: 1695
# step:  5300, Cost: 7.5549e+02, elapsed time: 1713
# step:  5400, Cost: 7.5551e+02, elapsed time: 1731
# step:  5500, Cost: 7.5553e+02, elapsed time: 1749
# step:  5600, Cost: 7.5550e+02, elapsed time: 1767
# step:  5700, Cost: 7.5550e+02, elapsed time: 1785
# step:  5800, Cost: 7.5548e+02, elapsed time: 1804
# step:  5900, Cost: 7.5549e+02, elapsed time: 1822
# step:  6000, Cost: 7.5546e+02, elapsed time: 1839
# step:  6100, Cost: 7.5544e+02, elapsed time: 1857
# step:  6200, Cost: 7.5541e+02, elapsed time: 1874
# step:  6300, Cost: 7.5541e+02, elapsed time: 1892
# step:  6400, Cost: 7.5543e+02, elapsed time: 1910
# step:  6500, Cost: 7.5540e+02, elapsed time: 1927
# step:  6600, Cost: 7.5534e+02, elapsed time: 1944
# step:  6700, Cost: 7.5536e+02, elapsed time: 1962
# step:  6800, Cost: 7.5533e+02, elapsed time: 1979
# step:  6900, Cost: 7.5533e+02, elapsed time: 1998
# step:  7000, Cost: 7.5532e+02, elapsed time: 2018
# step:  7100, Cost: 7.5528e+02, elapsed time: 2037
# step:  7200, Cost: 7.5524e+02, elapsed time: 2056
# step:  7300, Cost: 7.5523e+02, elapsed time: 2075
# step:  7400, Cost: 7.5518e+02, elapsed time: 2093
# step:  7500, Cost: 7.5517e+02, elapsed time: 2113
# step:  7600, Cost: 7.5519e+02, elapsed time: 2133
# step:  7700, Cost: 7.5520e+02, elapsed time: 2152
# step:  7800, Cost: 7.5518e+02, elapsed time: 2172
# step:  7900, Cost: 7.5518e+02, elapsed time: 2192
# step:  8000, Cost: 7.5520e+02, elapsed time: 2211
# step:  8100, Cost: 7.5520e+02, elapsed time: 2232
# step:  8200, Cost: 7.5520e+02, elapsed time: 2251
# step:  8300, Cost: 7.5520e+02, elapsed time: 2270
# step:  8400, Cost: 7.5520e+02, elapsed time: 2288
# step:  8500, Cost: 7.5520e+02, elapsed time: 2307
# step:  8600, Cost: 7.5520e+02, elapsed time: 2325
# step:  8700, Cost: 7.5520e+02, elapsed time: 2342
# step:  8800, Cost: 7.5520e+02, elapsed time: 2360
# step:  8900, Cost: 7.5520e+02, elapsed time: 2378
# step:  9000, Cost: 7.5520e+02, elapsed time: 2395
# step:  9100, Cost: 7.5520e+02, elapsed time: 2413
# step:  9200, Cost: 7.5520e+02, elapsed time: 2431
# step:  9300, Cost: 7.5520e+02, elapsed time: 2449
# step:  9400, Cost: 7.5520e+02, elapsed time: 2467
# step:  9500, Cost: 7.5520e+02, elapsed time: 2484
# step:  9600, Cost: 7.5520e+02, elapsed time: 2502
# step:  9700, Cost: 7.5520e+02, elapsed time: 2520
# step:  9800, Cost: 7.5520e+02, elapsed time: 2537
# step:  9900, Cost: 7.5520e+02, elapsed time: 2555
# step: 10000, Cost: 7.5520e+02, elapsed time: 2572
# Solving is done!

# %%
loss_val = output_table[:, 2]
for i in range(K-1):
    loss_val = loss_val + output_table[:, i+3]
average_cost = loss_val/K
print(average_cost)
# Out:
# [679.98391101 675.83581295 673.12314853 668.38949644 664.68014334
#  662.75580759 660.90354082 659.60823353 658.68316821 657.81382704
#  655.74978731 654.99931403 653.69932985 653.66781939 652.18958771
#  651.71131108 651.50515341 651.21882242 650.23680247 649.79375357
#  650.08321155 649.45501725 649.26900063 649.34580023 649.09069844
#  649.39811535 648.34327134 648.30915957 648.26135549 648.26017621
#  648.20085021 647.71736962 647.86644829 648.12633517 648.18068782
#  647.368616   647.55719426 647.68545561 647.59624587 647.17050835
#  647.10711111 647.1650001  647.19767444 647.13889692 647.58436707
#  647.51830881 647.00015175 646.96724639 647.15600293 647.31129321
#  647.21126138 647.18668263 647.15426978 647.14344397 647.13339233
#  647.11406788 647.10075561 647.0784836  647.10408235 647.10169687
#  647.09111166 647.0832435  647.0434186  647.01017281 647.00074216
#  646.99310811 646.97911194 646.95978279 646.95805723 646.95906855
#  646.92885949 646.9374049  646.90805373 646.88563478 646.85727227
#  646.84548311 646.80573894 646.82136082 646.78254941 646.77984454
#  646.81241051 646.81212689 646.81194238 646.81204647 646.81185734
#  646.81171793 646.81154223 646.81166191 646.81127889 646.81103495
#  646.81073021 646.81049682 646.81056515 646.8100155  646.81015074
#  646.8100949  646.80990647 646.81017382 646.81046438 646.81037763
#  646.81061863]

# %%
print(output_table)
#cost1 = output_table[:, 2]
#cost2 = output_table[:, 3]
#cost3 = output_table[:, 4]

# Compute averages
#average_cost = (cost1 + cost2+ cost3) / 3
#print(average_cost)
# Out:
# [[0.00000000e+00 6.27095199e+00 7.80764941e+02 5.96236869e+02
#   5.85567279e+02 6.39306720e+02 7.98043746e+02]
#  [1.00000000e+02 4.78530246e+02 7.75774894e+02 5.91291125e+02
#   5.77380441e+02 6.42799160e+02 7.91933445e+02]
#  [2.00000000e+02 4.96072410e+02 7.74171242e+02 5.87376149e+02
#   5.72523845e+02 6.42325760e+02 7.89218746e+02]
#  [3.00000000e+02 5.14140410e+02 7.72274069e+02 5.82605041e+02
#   5.64788808e+02 6.35890823e+02 7.86388741e+02]
#  [4.00000000e+02 5.32340133e+02 7.69112170e+02 5.77940662e+02
#   5.62563775e+02 6.31337685e+02 7.82446425e+02]
#  [5.00000000e+02 5.50535218e+02 7.66838040e+02 5.74085230e+02
#   5.64690213e+02 6.28964584e+02 7.79200972e+02]
#  [6.00000000e+02 5.68573741e+02 7.65648120e+02 5.71792871e+02
#   5.61031189e+02 6.30908521e+02 7.75137002e+02]
#  [7.00000000e+02 5.86752755e+02 7.65586789e+02 5.69387842e+02
#   5.62105255e+02 6.28489831e+02 7.72471450e+02]
#  [8.00000000e+02 6.04788832e+02 7.65101691e+02 5.67148394e+02
#   5.63803891e+02 6.27079512e+02 7.70282354e+02]
#  [9.00000000e+02 6.22912517e+02 7.65371691e+02 5.66032995e+02
#   5.61022895e+02 6.27006105e+02 7.69635450e+02]
#  [1.00000000e+03 6.41175694e+02 7.64812728e+02 5.64556341e+02
#   5.56771431e+02 6.25882125e+02 7.66726313e+02]
#  [1.10000000e+03 6.59287703e+02 7.65072688e+02 5.62559282e+02
#   5.55175140e+02 6.25292555e+02 7.66896906e+02]
#  [1.20000000e+03 6.77917603e+02 7.63054509e+02 5.61036624e+02
#   5.52130605e+02 6.25748281e+02 7.66526630e+02]
#  [1.30000000e+03 6.96282214e+02 7.62800187e+02 5.60208189e+02
#   5.54507028e+02 6.25434880e+02 7.65388813e+02]
#  [1.40000000e+03 7.14921974e+02 7.63939939e+02 5.59274333e+02
#   5.49913131e+02 6.23585405e+02 7.64235130e+02]
#  [1.50000000e+03 7.33814557e+02 7.63163054e+02 5.58228495e+02
#   5.49597379e+02 6.23989019e+02 7.63578608e+02]
#  [1.60000000e+03 7.52012342e+02 7.64724921e+02 5.57343264e+02
#   5.47754489e+02 6.24215194e+02 7.63487899e+02]
#  [1.70000000e+03 7.70239530e+02 7.63568777e+02 5.56488446e+02
#   5.49848901e+02 6.23226045e+02 7.62961943e+02]
#  [1.80000000e+03 7.88322307e+02 7.64567626e+02 5.55839273e+02
#   5.46292802e+02 6.22861211e+02 7.61623100e+02]
#  [1.90000000e+03 8.06503187e+02 7.64294536e+02 5.55408159e+02
#   5.44718275e+02 6.22994102e+02 7.61553695e+02]
#  [2.00000000e+03 8.24766319e+02 7.65336123e+02 5.54698495e+02
#   5.45777577e+02 6.23643349e+02 7.60960515e+02]
#  [2.10000000e+03 8.43093834e+02 7.64526922e+02 5.54324086e+02
#   5.44644125e+02 6.23425117e+02 7.60354836e+02]
#  [2.20000000e+03 8.61443176e+02 7.65141641e+02 5.53957877e+02
#   5.44032960e+02 6.22966414e+02 7.60246112e+02]
#  [2.30000000e+03 8.79616592e+02 7.65404794e+02 5.53697745e+02
#   5.45173207e+02 6.22289867e+02 7.60163388e+02]
#  [2.40000000e+03 8.97952156e+02 7.65336510e+02 5.53326268e+02
#   5.45134532e+02 6.21917752e+02 7.59738430e+02]
#  [2.50000000e+03 9.16395983e+02 7.65806987e+02 5.52790858e+02
#   5.45838067e+02 6.22755311e+02 7.59799354e+02]
#  [2.60000000e+03 9.35636565e+02 7.64333598e+02 5.52865984e+02
#   5.43436637e+02 6.22181153e+02 7.58898985e+02]
#  [2.70000000e+03 9.54705363e+02 7.64490714e+02 5.52830331e+02
#   5.43135485e+02 6.22787916e+02 7.58301353e+02]
#  [2.80000000e+03 9.73284749e+02 7.64110954e+02 5.52827070e+02
#   5.43882774e+02 6.22273802e+02 7.58212177e+02]
#  [2.90000000e+03 9.91485781e+02 7.64352692e+02 5.52746085e+02
#   5.43127352e+02 6.22983087e+02 7.58091665e+02]
#  [3.00000000e+03 1.00964961e+03 7.64819718e+02 5.52350417e+02
#   5.42774582e+02 6.22631386e+02 7.58428149e+02]
#  [3.10000000e+03 1.02797964e+03 7.65235811e+02 5.51904247e+02
#   5.40697575e+02 6.22670569e+02 7.58078646e+02]
#  [3.20000000e+03 1.04624852e+03 7.66978883e+02 5.51616252e+02
#   5.39697060e+02 6.23306847e+02 7.57733200e+02]
#  [3.30000000e+03 1.06457590e+03 7.66277707e+02 5.51776930e+02
#   5.40566192e+02 6.23870884e+02 7.58139963e+02]
#  [3.40000000e+03 1.08279441e+03 7.66673353e+02 5.51901920e+02
#   5.40353529e+02 6.23924643e+02 7.58049994e+02]
#  [3.50000000e+03 1.10076181e+03 7.65107262e+02 5.51630691e+02
#   5.39185008e+02 6.23288068e+02 7.57632051e+02]
#  [3.60000000e+03 1.11889338e+03 7.65702272e+02 5.51315972e+02
#   5.40804442e+02 6.22717150e+02 7.57246135e+02]
#  [3.70000000e+03 1.13709188e+03 7.66056399e+02 5.51189878e+02
#   5.41124648e+02 6.23492065e+02 7.56564288e+02]
#  [3.80000000e+03 1.15618732e+03 7.66519290e+02 5.51135918e+02
#   5.41035693e+02 6.22795999e+02 7.56494330e+02]
#  [3.90000000e+03 1.17517920e+03 7.66026623e+02 5.51016200e+02
#   5.39767020e+02 6.22869884e+02 7.56172815e+02]
#  [4.00000000e+03 1.19365384e+03 7.66722248e+02 5.51029928e+02
#   5.39463261e+02 6.22118546e+02 7.56201572e+02]
#  [4.10000000e+03 1.21182889e+03 7.66665092e+02 5.50628233e+02
#   5.39493511e+02 6.22873573e+02 7.56164592e+02]
#  [4.20000000e+03 1.23065771e+03 7.67046147e+02 5.50723901e+02
#   5.39074229e+02 6.22852035e+02 7.56292059e+02]
#  [4.30000000e+03 1.24925054e+03 7.65674559e+02 5.50446210e+02
#   5.39560728e+02 6.23708591e+02 7.56304397e+02]
#  [4.40000000e+03 1.26785718e+03 7.67629440e+02 5.50144827e+02
#   5.40545332e+02 6.23285388e+02 7.56316848e+02]
#  [4.50000000e+03 1.28645232e+03 7.67557236e+02 5.50391500e+02
#   5.40060453e+02 6.23278888e+02 7.56303467e+02]
#  [4.60000000e+03 1.30482640e+03 7.66023949e+02 5.50193657e+02
#   5.40197567e+02 6.22769782e+02 7.55815804e+02]
#  [4.70000000e+03 1.32312148e+03 7.65482659e+02 5.50407645e+02
#   5.40000590e+02 6.23181084e+02 7.55764255e+02]
#  [4.80000000e+03 1.34148326e+03 7.66916989e+02 5.50266259e+02
#   5.40149583e+02 6.22848188e+02 7.55598996e+02]
#  [4.90000000e+03 1.35976105e+03 7.67052458e+02 5.50264602e+02
#   5.40346823e+02 6.23317889e+02 7.55574693e+02]
#  [5.00000000e+03 1.37818825e+03 7.67085164e+02 5.50072414e+02
#   5.40162086e+02 6.23213307e+02 7.55523336e+02]
#  [5.10000000e+03 1.39685348e+03 7.67010102e+02 5.50056410e+02
#   5.40127631e+02 6.23256915e+02 7.55482355e+02]
#  [5.20000000e+03 1.41530336e+03 7.66936521e+02 5.50046106e+02
#   5.40051204e+02 6.23249603e+02 7.55487915e+02]
#  [5.30000000e+03 1.43378068e+03 7.66862873e+02 5.50042201e+02
#   5.40091963e+02 6.23228421e+02 7.55491762e+02]
#  [5.40000000e+03 1.45219194e+03 7.66806104e+02 5.50029248e+02
#   5.40114838e+02 6.23210307e+02 7.55506464e+02]
#  [5.50000000e+03 1.47097155e+03 7.66762956e+02 5.50019288e+02
#   5.40094571e+02 6.23165974e+02 7.55527550e+02]
#  [5.60000000e+03 1.48949696e+03 7.66791799e+02 5.50020689e+02
#   5.40045693e+02 6.23149496e+02 7.55496101e+02]
#  [5.70000000e+03 1.50837143e+03 7.66772356e+02 5.50008233e+02
#   5.40015277e+02 6.23095923e+02 7.55500628e+02]
#  [5.80000000e+03 1.52741186e+03 7.66816225e+02 5.50002895e+02
#   5.40117634e+02 6.23100150e+02 7.55483507e+02]
#  [5.90000000e+03 1.54614303e+03 7.66814974e+02 5.49978529e+02
#   5.40167108e+02 6.23061390e+02 7.55486484e+02]
#  [6.00000000e+03 1.56446424e+03 7.66773679e+02 5.49971049e+02
#   5.40186551e+02 6.23064380e+02 7.55459900e+02]
#  [6.10000000e+03 1.58329193e+03 7.66774431e+02 5.49975807e+02
#   5.40158214e+02 6.23071295e+02 7.55436470e+02]
#  [6.20000000e+03 1.60173479e+03 7.66667502e+02 5.49965054e+02
#   5.40143994e+02 6.23028061e+02 7.55412482e+02]
#  [6.30000000e+03 1.62041689e+03 7.66553623e+02 5.49911754e+02
#   5.40157079e+02 6.23018099e+02 7.55410309e+02]
#  [6.40000000e+03 1.63895550e+03 7.66486698e+02 5.49888418e+02
#   5.40148656e+02 6.23049475e+02 7.55430465e+02]
#  [6.50000000e+03 1.65742666e+03 7.66455368e+02 5.49896038e+02
#   5.40111769e+02 6.23106494e+02 7.55395872e+02]
#  [6.60000000e+03 1.67650437e+03 7.66503192e+02 5.49863290e+02
#   5.40086639e+02 6.23099310e+02 7.55343129e+02]
#  [6.70000000e+03 1.69559309e+03 7.66439179e+02 5.49881408e+02
#   5.40038143e+02 6.23084654e+02 7.55355529e+02]
#  [6.80000000e+03 1.71552769e+03 7.66365850e+02 5.49854109e+02
#   5.40064646e+02 6.23171277e+02 7.55334404e+02]
#  [6.90000000e+03 1.73614610e+03 7.66339076e+02 5.49817045e+02
#   5.40096315e+02 6.23215108e+02 7.55327799e+02]
#  [7.00000000e+03 1.75693972e+03 7.66310416e+02 5.49812015e+02
#   5.39985835e+02 6.23218445e+02 7.55317586e+02]
#  [7.10000000e+03 1.77817277e+03 7.66315649e+02 5.49830399e+02
#   5.40008457e+02 6.23249905e+02 7.55282615e+02]
#  [7.20000000e+03 1.79897403e+03 7.66262686e+02 5.49807195e+02
#   5.40014243e+02 6.23216778e+02 7.55239366e+02]
#  [7.30000000e+03 1.81961720e+03 7.66332276e+02 5.49798923e+02
#   5.39974557e+02 6.23094809e+02 7.55227609e+02]
#  [7.40000000e+03 1.84042624e+03 7.66261878e+02 5.49787798e+02
#   5.40024584e+02 6.23028523e+02 7.55183579e+02]
#  [7.50000000e+03 1.86094053e+03 7.66263892e+02 5.49789809e+02
#   5.39933564e+02 6.23066237e+02 7.55173914e+02]
#  [7.60000000e+03 1.88167964e+03 7.66166063e+02 5.49806621e+02
#   5.39813778e+02 6.23049573e+02 7.55192661e+02]
#  [7.70000000e+03 1.90239108e+03 7.66190273e+02 5.49800604e+02
#   5.39778486e+02 6.23138660e+02 7.55198781e+02]
#  [7.80000000e+03 1.92305348e+03 7.66157172e+02 5.49806517e+02
#   5.39668559e+02 6.23101212e+02 7.55179289e+02]
#  [7.90000000e+03 1.94335670e+03 7.66246721e+02 5.49783381e+02
#   5.39592327e+02 6.23101252e+02 7.55175542e+02]
#  [8.00000000e+03 1.96408265e+03 7.66297305e+02 5.49777637e+02
#   5.39666090e+02 6.23120760e+02 7.55200260e+02]
#  [8.10000000e+03 1.98546850e+03 7.66295422e+02 5.49777888e+02
#   5.39668393e+02 6.23119055e+02 7.55199877e+02]
#  [8.20000000e+03 2.00654000e+03 7.66295284e+02 5.49778060e+02
#   5.39667344e+02 6.23119466e+02 7.55199557e+02]
#  [8.30000000e+03 2.02726936e+03 7.66294531e+02 5.49777767e+02
#   5.39668058e+02 6.23120535e+02 7.55199341e+02]
#  [8.40000000e+03 2.04812109e+03 7.66294265e+02 5.49777624e+02
#   5.39667953e+02 6.23120569e+02 7.55198875e+02]
#  [8.50000000e+03 2.06872702e+03 7.66293928e+02 5.49777583e+02
#   5.39667969e+02 6.23120457e+02 7.55198652e+02]
#  [8.60000000e+03 2.08923289e+03 7.66293019e+02 5.49777512e+02
#   5.39668069e+02 6.23120366e+02 7.55198745e+02]
#  [8.70000000e+03 2.10993269e+03 7.66293184e+02 5.49777103e+02
#   5.39668806e+02 6.23120281e+02 7.55198936e+02]
#  [8.80000000e+03 2.13110537e+03 7.66292046e+02 5.49776838e+02
#   5.39668572e+02 6.23119761e+02 7.55199178e+02]
#  [8.90000000e+03 2.15569932e+03 7.66291819e+02 5.49776325e+02
#   5.39667910e+02 6.23120289e+02 7.55198832e+02]
#  [9.00000000e+03 2.17984934e+03 7.66291190e+02 5.49775957e+02
#   5.39667456e+02 6.23120077e+02 7.55198970e+02]
#  [9.10000000e+03 2.20340018e+03 7.66290449e+02 5.49775849e+02
#   5.39666688e+02 6.23120120e+02 7.55199379e+02]
#  [9.20000000e+03 2.22636148e+03 7.66290762e+02 5.49775886e+02
#   5.39666062e+02 6.23120859e+02 7.55199257e+02]
#  [9.30000000e+03 2.24932455e+03 7.66289845e+02 5.49775226e+02
#   5.39665141e+02 6.23120590e+02 7.55199276e+02]
#  [9.40000000e+03 2.27189956e+03 7.66290504e+02 5.49775020e+02
#   5.39665502e+02 6.23120481e+02 7.55199247e+02]
#  [9.50000000e+03 2.29561707e+03 7.66289812e+02 5.49775034e+02
#   5.39665220e+02 6.23121455e+02 7.55198954e+02]
#  [9.60000000e+03 2.31816721e+03 7.66289503e+02 5.49774717e+02
#   5.39664790e+02 6.23121883e+02 7.55198639e+02]
#  [9.70000000e+03 2.34120249e+03 7.66289785e+02 5.49774652e+02
#   5.39665469e+02 6.23122444e+02 7.55198519e+02]
#  [9.80000000e+03 2.36433042e+03 7.66290532e+02 5.49774872e+02
#   5.39665694e+02 6.23122841e+02 7.55198382e+02]
#  [9.90000000e+03 2.38700483e+03 7.66289890e+02 5.49774792e+02
#   5.39665963e+02 6.23122752e+02 7.55198491e+02]
#  [1.00000000e+04 2.40949083e+03 7.66289601e+02 5.49774656e+02
#   5.39667335e+02 6.23123187e+02 7.55198315e+02]]

# %%
t = np.linspace(0, len(average_cost), len(average_cost))
fig, ax0 = plt.subplots(1, 1, figsize =(16,6), dpi = 120, sharey = True)
ax0.plot(t, average_cost, lw = 0.5, color = 'mediumblue', label = 'average_cost')
ax0.set_xlabel('Iterations', fontsize = 12)
ax0.set_ylabel('Loss', fontsize = 12)
ax0.set_title('Loss function over time', fontsize = 12)
plt.savefig('Loss_'+str(TEXT)+'.png')

# %%
print(control_outs_table[1:2,:].flatten())
t = np.linspace(0, len(control_outs_table[1:2,:].flatten()),len(control_outs_table[1:2,:].flatten()))
fig, ax0 = plt.subplots(1, 1, figsize =(16,6), dpi = 120, sharey = True)
ax0.plot(control_outs_table[1:2,:].flatten(), lw = 0.5, color = 'mediumblue', label = 'average_cost')
ax0.set_xlabel('Time [days]', fontsize = 12)
ax0.set_ylabel('Vaccination rate', fontsize = 12)
ax0.set_title('Opt vacc', fontsize = 12)
plt.savefig('Opt vacc_'+str(TEXT)+'.png')
# Out:
# [0.02779238 0.02779364 0.02777908 0.0277652  0.02774483 0.02771842
#  0.0276919  0.02765782 0.0276195  0.02759212 0.02758777 0.0274788
#  0.02735175 0.02724824 0.02700016 0.02682102 0.02668823 0.02601331
#  0.02589798 0.02537831 0.02542113 0.02520719 0.02482232 0.02441107
#  0.02410446 0.02357463 0.02260577 0.02237954 0.02140986 0.0211201
#  0.0204932  0.01974279 0.01889145 0.01824752 0.01755979 0.01684881
#  0.01580487 0.01451969 0.01409828 0.01371764 0.01286003 0.01199756
#  0.0117005  0.01121949 0.01047532 0.00975381 0.00904845 0.00840785
#  0.00728986 0.00631161 0.00577726 0.00529639 0.00481492 0.00456052
#  0.00438913 0.0043051  0.00426842 0.00425403 0.00425233 0.00424854]

# %% [markdown]
# # simple model check
